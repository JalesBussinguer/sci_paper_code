# %% [markdown]
# ## Sigma0 Analysis - PNB

# %% [markdown]
# Pré-processamento: Orbit File -> Calibration -> Speckle Filtering -> Terrain Correction -> Spatial Subset

# %%
# Importações
# Bibliotecas básicas
import rasterio as rst
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from seaborn import pointplot

# Rasterio
import rasterio as rst
from rasterio.mask import mask
from rasterio.plot import show
# Raster stats
from rasterstats import zonal_stats
from rasterstats import point_query
# Processamento de dados
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
# Área de estudo no Parque Nacional de Brasília - Formação Florestal
area = gpd.read_file('C:/Users/jales/Desktop/PNB/classes/amostras_formacao_florestal_32723.GEOJSON')

# %% [markdown]
# ## Cálculo das estatísticas

# %% [markdown]
# #### 11/09/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20190911_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

ff_2019_09_11_VH = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
ff_2019_09_11_VH['date'] = '11/09/2019'
ff_2019_09_11_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019

# %%
# Zonal stats das formações florestais - VV
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20190911_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)
ff_2019_09_11_VV = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
ff_2019_09_11_VV['date'] = '11/09/2019'
ff_2019_09_11_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019

# %% [markdown]
# #### 23/09/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20190923_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

ff_2019_09_23_VH = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
ff_2019_09_23_VH['date'] = '23/09/2019'
ff_2019_09_23_VH
# Out:
#     mediana        Q25        Q75        date
# 0 -14.81317 -16.004134 -13.728835  23/09/2019

# %%
df_VH = ff_2019_09_11_VH.append(ff_2019_09_23_VH)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019

# %%
# Zonal stats das formações florestais - VV
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20190923_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

ff_2019_09_23_VV = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
ff_2019_09_23_VV['date'] = '23/09/2019'
ff_2019_09_23_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -8.981833 -10.130686 -7.735123  23/09/2019

# %%
df_VV = ff_2019_09_11_VV.append(ff_2019_09_23_VV)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019

# %% [markdown]
# #### 05/10/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191005_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

ff_2019_10_05_VH = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
ff_2019_10_05_VH['date'] = '05/10/2019'
ff_2019_10_05_VH
# Out:
#      mediana        Q25      Q75        date
# 0 -14.846338 -15.884956 -13.8563  05/10/2019

# %%
df_VH = df_VH.append(ff_2019_10_05_VH)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019

# %%
# Zonal stats das formações florestais - VV
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191005_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

ff_2019_10_05_VV = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
ff_2019_10_05_VV['date'] = '05/10/2019'
ff_2019_10_05_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.062409 -10.278637 -7.899869  05/10/2019

# %%
df_VV = df_VV.append(ff_2019_10_05_VV)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019

# %% [markdown]
# #### 17/10/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191017_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2019_10_17 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2019_10_17['date'] = '17/10/2019'
VH_2019_10_17
# Out:
#      mediana        Q25        Q75        date
# 0 -14.862182 -16.130614 -13.860002  17/10/2019

# %%
df_VH = df_VH.append(VH_2019_10_17)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019

# %%
# Zonal stats das formações florestais - VV
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191017_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2019_10_17 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2019_10_17['date'] = '17/10/2019'
VV_2019_10_17
# Out:
#     mediana        Q25       Q75        date
# 0 -8.944348 -10.350341 -7.898506  17/10/2019

# %%
df_VV = df_VV.append(VV_2019_10_17)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019

# %% [markdown]
# #### 29/10/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191029_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2019_10_29 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2019_10_29['date'] = '29/10/2019'
VH_2019_10_29
# Out:
#      mediana        Q25        Q75        date
# 0 -14.689231 -15.713686 -13.827491  29/10/2019

# %%
df_VH = df_VH.append(VH_2019_10_29)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019

# %%
# Zonal stats das formações florestais - VV
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191029_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2019_10_29 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2019_10_29['date'] = '29/10/2019'
VV_2019_10_29
# Out:
#     mediana        Q25       Q75        date
# 0 -8.904564 -10.047134 -7.813156  29/10/2019

# %%
df_VV = df_VV.append(VV_2019_10_29)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019

# %% [markdown]
# #### 10/11/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191110_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2019_11_10 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2019_11_10['date'] = '10/11/2019'
VH_2019_11_10
# Out:
#      mediana       Q25        Q75        date
# 0 -14.584137 -15.57288 -13.628555  10/11/2019

# %%
df_VH = df_VH.append(VH_2019_11_10)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019

# %%
# Zonal stats das formações florestais - VV
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191110_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2019_11_10 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2019_11_10['date'] = '10/11/2019'
VV_2019_11_10
# Out:
#     mediana       Q25       Q75        date
# 0 -8.488308 -9.529229 -7.481115  10/11/2019

# %%
df_VV = df_VV.append(VV_2019_11_10)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019

# %% [markdown]
# #### 22/11/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191122_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2019_11_22 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2019_11_22['date'] = '22/11/2019'
VH_2019_11_22
# Out:
#      mediana        Q25       Q75        date
# 0 -13.313608 -14.331385 -12.42409  22/11/2019

# %%
df_VH = df_VH.append(VH_2019_11_22)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019

# %%
# Zonal stats das formações florestais - VV
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191122_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2019_11_22 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2019_11_22['date'] = '22/11/2019'
VV_2019_11_22
# Out:
#     mediana       Q25       Q75        date
# 0 -7.685743 -8.813491 -6.793098  22/11/2019

# %%
df_VV = df_VV.append(VV_2019_11_22)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019

# %% [markdown]
# #### 04/12/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191204_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2019_12_04 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2019_12_04['date'] = '04/12/2019'
VH_2019_12_04
# Out:
#      mediana        Q25        Q75        date
# 0 -13.600591 -14.690894 -12.608731  04/12/2019

# %%
df_VH = df_VH.append(VH_2019_12_04)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019

# %%
# Zonal stats das formações florestais - VV
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191204_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2019_12_04 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2019_12_04['date'] = '04/12/2019'
VV_2019_12_04
# Out:
#     mediana       Q25       Q75        date
# 0 -7.974712 -8.990287 -6.993795  04/12/2019

# %%
df_VV = df_VV.append(VV_2019_12_04)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019

# %% [markdown]
# #### 16/12/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191216_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2019_12_16 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2019_12_16['date'] = '16/12/2019'
VH_2019_12_16
# Out:
#      mediana        Q25        Q75        date
# 0 -14.111507 -15.086475 -13.228961  16/12/2019

# %%
df_VH = df_VH.append(VH_2019_12_16)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019

# %%
# Zonal stats das formações florestais - VV
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191216_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2019_12_16 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2019_12_16['date'] = '16/12/2019'
VV_2019_12_16
# Out:
#     mediana       Q25       Q75        date
# 0 -8.171959 -9.356175 -7.164786  16/12/2019

# %%
df_VV = df_VV.append(VV_2019_12_16)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019

# %% [markdown]
# #### 28/12/2019

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191228_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2019_12_28 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2019_12_28['date'] = '28/12/2019'
VH_2019_12_28
# Out:
#      mediana        Q25        Q75        date
# 0 -14.492561 -15.292249 -13.453428  28/12/2019

# %%
df_VH = df_VH.append(VH_2019_12_28)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019

# %%
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191228_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2019_12_28 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2019_12_28['date'] = '28/12/2019'
VV_2019_12_28
# Out:
#     mediana       Q25       Q75        date
# 0 -8.568241 -9.655109 -7.574184  28/12/2019

# %%
df_VV = df_VV.append(VV_2019_12_28)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019

# %% [markdown]
# #### 09/01/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200109_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_01_09 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_01_09['date'] = '09/01/2020'
VH_2020_01_09
# Out:
#      mediana        Q25        Q75        date
# 0 -14.287342 -15.103656 -13.297688  09/01/2020

# %%
df_VH = df_VH.append(VH_2020_01_09)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200109_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_01_09 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_01_09['date'] = '09/01/2020'
VV_2020_01_09
# Out:
#     mediana       Q25       Q75        date
# 0 -8.200825 -9.239112 -7.081237  09/01/2020

# %%
df_VV = df_VV.append(VV_2020_01_09)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020

# %% [markdown]
# #### 21/01/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200121_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_01_21 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_01_21['date'] = '21/01/2020'
VH_2020_01_21
# Out:
#      mediana        Q25        Q75        date
# 0 -13.808728 -14.812275 -12.908787  21/01/2020

# %%
df_VH = df_VH.append(VH_2020_01_21)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200121_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_01_21 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_01_21['date'] = '21/01/2020'
VV_2020_01_21
# Out:
#     mediana       Q25       Q75        date
# 0 -8.008898 -8.922173 -6.938013  21/01/2020

# %%
df_VV = df_VV.append(VV_2020_01_21)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020

# %% [markdown]
# #### 02/02/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200202_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_02_02 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_02_02['date'] = '02/02/2020'
VH_2020_02_02
# Out:
#      mediana        Q25        Q75        date
# 0 -14.405014 -15.436635 -13.509724  02/02/2020

# %%
df_VH = df_VH.append(VH_2020_02_02)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200202_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_02_02 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_02_02['date'] = '02/02/2020'
VV_2020_02_02
# Out:
#     mediana       Q25       Q75        date
# 0 -8.383687 -9.310959 -7.258154  02/02/2020

# %%
df_VV = df_VV.append(VV_2020_02_02)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020

# %% [markdown]
# #### 14/02/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200214_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_02_14 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_02_14['date'] = '14/02/2020'
VH_2020_02_14
# Out:
#      mediana        Q25        Q75        date
# 0 -13.592594 -14.527619 -12.625504  14/02/2020

# %%
df_VH = df_VH.append(VH_2020_02_14)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200214_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_02_14 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_02_14['date'] = '14/02/2020'
VV_2020_02_14
# Out:
#     mediana       Q25       Q75        date
# 0 -7.707244 -8.812419 -6.909062  14/02/2020

# %%
df_VV = df_VV.append(VV_2020_02_14)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020

# %% [markdown]
# #### 26/02/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200226_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_02_26 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_02_26['date'] = '26/02/2020'
VH_2020_02_26
# Out:
#      mediana        Q25        Q75        date
# 0 -13.708881 -14.807408 -12.748839  26/02/2020

# %%
df_VH = df_VH.append(VH_2020_02_26)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200226_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_02_26 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_02_26['date'] = '26/02/2020'
VV_2020_02_26
# Out:
#     mediana       Q25       Q75        date
# 0 -7.841531 -8.915773 -6.658035  26/02/2020

# %%
df_VV = df_VV.append(VV_2020_02_26)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020

# %% [markdown]
# #### 09/03/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200309_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_03_09 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_03_09['date'] = '09/03/2020'
VH_2020_03_09
# Out:
#    mediana        Q25        Q75        date
# 0 -13.6636 -14.636651 -12.731178  09/03/2020

# %%
df_VH = df_VH.append(VH_2020_03_09)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200309_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_03_09 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_03_09['date'] = '09/03/2020'
VV_2020_03_09
# Out:
#     mediana       Q25       Q75        date
# 0 -7.622122 -8.759349 -6.797528  09/03/2020

# %%
df_VV = df_VV.append(VV_2020_03_09)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020

# %% [markdown]
# #### 21/03/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200321_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_03_21 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_03_21['date'] = '21/03/2020'
VH_2020_03_21
# Out:
#      mediana        Q25        Q75        date
# 0 -13.718564 -14.588722 -12.845869  21/03/2020

# %%
df_VH = df_VH.append(VH_2020_03_21)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200321_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_03_21 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_03_21['date'] = '21/03/2020'
VV_2020_03_21
# Out:
#     mediana       Q25       Q75        date
# 0 -7.927097 -8.930521 -6.944872  21/03/2020

# %%
df_VV = df_VV.append(VV_2020_03_21)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020

# %% [markdown]
# #### 02/04/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200402_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_04_02 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_04_02['date'] = '02/04/2020'
VH_2020_04_02
# Out:
#      mediana        Q25        Q75        date
# 0 -14.108388 -15.167422 -13.249794  02/04/2020

# %%
df_VH = df_VH.append(VH_2020_04_02)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200402_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_04_02 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_04_02['date'] = '02/04/2020'
VV_2020_04_02
# Out:
#     mediana       Q25      Q75        date
# 0 -8.025056 -8.962089 -7.02631  02/04/2020

# %%
df_VV = df_VV.append(VV_2020_04_02)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020

# %% [markdown]
# #### 14/04/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200414_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_04_14 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_04_14['date'] = '14/04/2020'
VH_2020_04_14
# Out:
#      mediana        Q25        Q75        date
# 0 -13.779643 -14.587924 -12.579703  14/04/2020

# %%
df_VH = df_VH.append(VH_2020_04_14)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200414_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_04_14 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_04_14['date'] = '14/04/2020'
VV_2020_04_14
# Out:
#     mediana       Q25       Q75        date
# 0 -7.691808 -8.722047 -6.533518  14/04/2020

# %%
df_VV = df_VV.append(VV_2020_04_14)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020

# %% [markdown]
# #### 26/04/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200426_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_04_26 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_04_26['date'] = '26/04/2020'
VH_2020_04_26
# Out:
#      mediana       Q25       Q75        date
# 0 -14.138226 -15.07344 -13.20427  26/04/2020

# %%
df_VH = df_VH.append(VH_2020_04_26)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200426_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_04_26 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_04_26['date'] = '26/04/2020'
VV_2020_04_26
# Out:
#     mediana       Q25       Q75        date
# 0 -7.884557 -8.907589 -6.895229  26/04/2020

# %%
df_VV = df_VV.append(VV_2020_04_26)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020

# %% [markdown]
# #### 08/05/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200508_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_05_08 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_05_08['date'] = '08/05/2020'
VH_2020_05_08
# Out:
#     mediana        Q25       Q75        date
# 0 -14.12664 -14.977507 -13.23561  08/05/2020

# %%
df_VH = df_VH.append(VH_2020_05_08)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200508_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_05_08 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_05_08['date'] = '08/05/2020'
VV_2020_05_08
# Out:
#     mediana       Q25       Q75        date
# 0 -8.331831 -9.340714 -7.304558  08/05/2020

# %%
df_VV = df_VV.append(VV_2020_05_08)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 20/05/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200520_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_05_20 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_05_20['date'] = '20/05/2020'
VH_2020_05_20
# Out:
#      mediana        Q25        Q75        date
# 0 -14.367209 -15.358352 -13.550475  20/05/2020

# %%
df_VH = df_VH.append(VH_2020_05_20)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200520_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_05_20 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_05_20['date'] = '20/05/2020'
VV_2020_05_20
# Out:
#     mediana       Q25       Q75        date
# 0 -8.305255 -9.314909 -7.177232  20/05/2020

# %%
df_VV = df_VV.append(VV_2020_05_20)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 01/06/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200601_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_06_01 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_06_01['date'] = '01/06/2020'
VH_2020_06_01
# Out:
#      mediana        Q25        Q75        date
# 0 -14.749935 -15.762452 -13.819614  01/06/2020

# %%
df_VH = df_VH.append(VH_2020_06_01)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200601_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_06_01 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_06_01['date'] = '01/06/2020'
VV_2020_06_01
# Out:
#     mediana       Q25       Q75        date
# 0 -8.553537 -9.623158 -7.450383  01/06/2020

# %%
df_VV = df_VV.append(VV_2020_06_01)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 13/06/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200613_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_06_13 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_06_13['date'] = '13/06/2020'
VH_2020_06_13
# Out:
#      mediana       Q25        Q75        date
# 0 -14.873873 -15.81163 -13.805379  13/06/2020

# %%
df_VH = df_VH.append(VH_2020_06_13)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200613_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_06_13 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_06_13['date'] = '13/06/2020'
VV_2020_06_13
# Out:
#     mediana       Q25       Q75        date
# 0 -8.749715 -9.978978 -7.684963  13/06/2020

# %%
df_VV = df_VV.append(VV_2020_06_13)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 25/06/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200625_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_06_25 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_06_25['date'] = '25/06/2020'
VH_2020_06_25
# Out:
#      mediana        Q25        Q75        date
# 0 -14.470685 -15.373487 -13.379875  25/06/2020

# %%
df_VH = df_VH.append(VH_2020_06_25)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200625_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_06_25 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_06_25['date'] = '25/06/2020'
VV_2020_06_25
# Out:
#     mediana       Q25       Q75        date
# 0 -8.369973 -9.440866 -7.202853  25/06/2020

# %%
df_VV = df_VV.append(VV_2020_06_25)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 07/07/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200707_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_07_07 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_07_07['date'] = '07/07/2020'
VH_2020_07_07
# Out:
#      mediana        Q25        Q75        date
# 0 -14.768637 -15.871695 -13.817351  07/07/2020

# %%
df_VH = df_VH.append(VH_2020_07_07)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200707_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_07_07 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_07_07['date'] = '07/07/2020'
VV_2020_07_07
# Out:
#     mediana       Q25       Q75        date
# 0 -8.751466 -9.732784 -7.790893  07/07/2020

# %%
df_VV = df_VV.append(VV_2020_07_07)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 19/07/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200719_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_07_19 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_07_19['date'] = '19/07/2020'
VH_2020_07_19
# Out:
#      mediana        Q25        Q75        date
# 0 -14.982168 -15.978038 -13.786505  19/07/2020

# %%
df_VH = df_VH.append(VH_2020_07_19)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200719_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_07_19 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_07_19['date'] = '19/07/2020'
VV_2020_07_19
# Out:
#     mediana       Q25       Q75        date
# 0 -8.784655 -9.996719 -7.759323  19/07/2020

# %%
df_VV = df_VV.append(VV_2020_07_19)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 31/07/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200731_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_07_31 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_07_31['date'] = '31/07/2020'
VH_2020_07_31
# Out:
#      mediana        Q25        Q75        date
# 0 -15.080448 -16.283234 -14.016868  31/07/2020

# %%
df_VH = df_VH.append(VH_2020_07_31)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200731_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_07_31 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_07_31['date'] = '31/07/2020'
VV_2020_07_31
# Out:
#     mediana        Q25       Q75        date
# 0 -8.997119 -10.153057 -7.802405  31/07/2020

# %%
df_VV = df_VV.append(VV_2020_07_31)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 12/08/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200812_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_08_12 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_08_12['date'] = '12/08/2020'
VH_2020_08_12
# Out:
#      mediana        Q25        Q75        date
# 0 -14.930185 -15.991798 -13.905038  12/08/2020

# %%
df_VH = df_VH.append(VH_2020_08_12)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200812_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_08_12 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_08_12['date'] = '12/08/2020'
VV_2020_08_12
# Out:
#     mediana        Q25       Q75        date
# 0 -9.134478 -10.227344 -8.082596  12/08/2020

# %%
df_VV = df_VV.append(VV_2020_08_12)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 24/08/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200824_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_08_24 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_08_24['date'] = '24/08/2020'
VH_2020_08_24
# Out:
#      mediana        Q25        Q75        date
# 0 -14.606301 -15.544682 -13.613901  24/08/2020

# %%
df_VH = df_VH.append(VH_2020_08_24)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200824_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_08_24 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_08_24['date'] = '24/08/2020'
VV_2020_08_24
# Out:
#     mediana        Q25       Q75        date
# 0 -8.903068 -10.013193 -7.883714  24/08/2020

# %%
df_VV = df_VV.append(VV_2020_08_24)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 05/09/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200905_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_09_05 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_09_05['date'] = '05/09/2020'
VH_2020_09_05
# Out:
#      mediana        Q25        Q75        date
# 0 -15.299552 -16.342267 -14.179832  05/09/2020

# %%
df_VH = df_VH.append(VH_2020_09_05)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200905_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_09_05 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_09_05['date'] = '05/09/2020'
VV_2020_09_05
# Out:
#     mediana       Q25       Q75        date
# 0 -9.306118 -10.60405 -8.191985  05/09/2020

# %%
df_VV = df_VV.append(VV_2020_09_05)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 17/09/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200917_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_09_17 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_09_17['date'] = '17/09/2020'
VH_2020_09_17
# Out:
#      mediana        Q25        Q75        date
# 0 -15.173815 -16.167393 -13.884487  17/09/2020

# %%
df_VH = df_VH.append(VH_2020_09_17)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200917_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_09_17 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_09_17['date'] = '17/09/2020'
VV_2020_09_17
# Out:
#     mediana        Q25       Q75        date
# 0 -9.101729 -10.278051 -8.028512  17/09/2020

# %%
df_VV = df_VV.append(VV_2020_09_17)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %% [markdown]
# #### 29/09/2020

# %%
# Zonal stats das formações florestais - VH
stats_VH = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200929_Orb_Cal_Spk_TC_dB.tif', band=1, nodata=np.nan)
stats_VH = pd.DataFrame({'db':stats_VH})

mediana = np.median(stats_VH['db'])
Q25 = np.percentile(stats_VH['db'], 25)
Q75 = np.percentile(stats_VH['db'], 75)

VH_2020_09_29 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VH_2020_09_29['date'] = '29/09/2020'
VH_2020_09_29
# Out:
#      mediana        Q25        Q75        date
# 0 -15.144528 -16.054567 -13.840189  29/09/2020

# %%
df_VH = df_VH.append(VH_2020_09_29)
df_VH
# Out:
#      mediana        Q25        Q75        date
# 0 -15.198812 -16.163917 -14.110289  11/09/2019
# 0 -14.813170 -16.004134 -13.728835  23/09/2019
# 0 -14.846338 -15.884956 -13.856300  05/10/2019
# 0 -14.862182 -16.130614 -13.860002  17/10/2019
# 0 -14.689231 -15.713686 -13.827491  29/10/2019
# 0 -14.584137 -15.572880 -13.628555  10/11/2019
# 0 -13.313608 -14.331385 -12.424090  22/11/2019
# 0 -13.600591 -14.690894 -12.608731  04/12/2019
# 0 -14.111507 -15.086475 -13.228961  16/12/2019
# 0 -14.492561 -15.292249 -13.453428  28/12/2019
# 0 -14.287342 -15.103656 -13.297688  09/01/2020
# 0 -13.808728 -14.812275 -12.908787  21/01/2020
# 0 -14.405014 -15.436635 -13.509724  02/02/2020
# 0 -13.592594 -14.527619 -12.625504  14/02/2020
# 0 -13.708881 -14.807408 -12.748839  26/02/2020
# 0 -13.663600 -14.636651 -12.731178  09/03/2020
# 0 -13.718564 -14.588722 -12.845869  21/03/2020
# 0 -14.108388 -15.167422 -13.249794  02/04/2020
# 0 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
# Zonal stats das formações florestais - VH
stats_VV = point_query(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200929_Orb_Cal_Spk_TC_dB.tif', band=2, nodata=np.nan)
stats_VV = pd.DataFrame({'db':stats_VV})

mediana = np.median(stats_VV['db'])
Q25 = np.percentile(stats_VV['db'], 25)
Q75 = np.percentile(stats_VV['db'], 75)

VV_2020_09_29 = pd.DataFrame({'mediana':mediana, 'Q25':Q25, 'Q75':Q75}, index=[0])
VV_2020_09_29['date'] = '29/09/2020'
VV_2020_09_29
# Out:
#     mediana        Q25      Q75        date
# 0 -9.003607 -10.225729 -7.89088  29/09/2020

# %%
df_VV = df_VV.append(VV_2020_09_29)
df_VV
# Out:
#     mediana        Q25       Q75        date
# 0 -9.140947 -10.429954 -7.946793  11/09/2019
# 0 -8.981833 -10.130686 -7.735123  23/09/2019
# 0 -9.062409 -10.278637 -7.899869  05/10/2019
# 0 -8.944348 -10.350341 -7.898506  17/10/2019
# 0 -8.904564 -10.047134 -7.813156  29/10/2019
# 0 -8.488308  -9.529229 -7.481115  10/11/2019
# 0 -7.685743  -8.813491 -6.793098  22/11/2019
# 0 -7.974712  -8.990287 -6.993795  04/12/2019
# 0 -8.171959  -9.356175 -7.164786  16/12/2019
# 0 -8.568241  -9.655109 -7.574184  28/12/2019
# 0 -8.200825  -9.239112 -7.081237  09/01/2020
# 0 -8.008898  -8.922173 -6.938013  21/01/2020
# 0 -8.383687  -9.310959 -7.258154  02/02/2020
# 0 -7.707244  -8.812419 -6.909062  14/02/2020
# 0 -7.841531  -8.915773 -6.658035  26/02/2020
# 0 -7.622122  -8.759349 -6.797528  09/03/2020
# 0 -7.927097  -8.930521 -6.944872  21/03/2020
# 0 -8.025056  -8.962089 -7.026310  02/04/2020
# 0 -7.691808  -8.722047 -6.533518  14/04/2020
# 0 -7.884557  -8.907589 -6.895229  26/04/2020
# ...

# %%
df_VH = df_VH.reset_index(drop=True)
df_VH.to_csv('E:/SBSR_data/CSV/form_florestais_VH_amostras.csv', sep=',')

# %%
df_VH
# Out:
#       mediana        Q25        Q75        date
# 0  -15.198812 -16.163917 -14.110289  11/09/2019
# 1  -14.813170 -16.004134 -13.728835  23/09/2019
# 2  -14.846338 -15.884956 -13.856300  05/10/2019
# 3  -14.862182 -16.130614 -13.860002  17/10/2019
# 4  -14.689231 -15.713686 -13.827491  29/10/2019
# 5  -14.584137 -15.572880 -13.628555  10/11/2019
# 6  -13.313608 -14.331385 -12.424090  22/11/2019
# 7  -13.600591 -14.690894 -12.608731  04/12/2019
# 8  -14.111507 -15.086475 -13.228961  16/12/2019
# 9  -14.492561 -15.292249 -13.453428  28/12/2019
# 10 -14.287342 -15.103656 -13.297688  09/01/2020
# 11 -13.808728 -14.812275 -12.908787  21/01/2020
# 12 -14.405014 -15.436635 -13.509724  02/02/2020
# 13 -13.592594 -14.527619 -12.625504  14/02/2020
# 14 -13.708881 -14.807408 -12.748839  26/02/2020
# 15 -13.663600 -14.636651 -12.731178  09/03/2020
# 16 -13.718564 -14.588722 -12.845869  21/03/2020
# 17 -14.108388 -15.167422 -13.249794  02/04/2020
# 18 -13.779643 -14.587924 -12.579703  14/04/2020
# ...

# %%
print('min =', df_VH['mediana'].min())
print('max =', df_VH['mediana'].max())
print('amplitude = ', df_VH['mediana'].max() - df_VH['mediana'].min())
# Out:
# min = -15.299552352527892
# max = -13.313608037785913
# amplitude =  1.9859443147419782

# %%
df_VV = df_VV.reset_index(drop=True)
df_VV.to_csv('E:/SBSR_data/CSV/form_florestais_VV_amostras.csv', sep=',')

# %%
df_VV
# Out:
#      mediana        Q25       Q75        date
# 0  -9.140947 -10.429954 -7.946793  11/09/2019
# 1  -8.981833 -10.130686 -7.735123  23/09/2019
# 2  -9.062409 -10.278637 -7.899869  05/10/2019
# 3  -8.944348 -10.350341 -7.898506  17/10/2019
# 4  -8.904564 -10.047134 -7.813156  29/10/2019
# 5  -8.488308  -9.529229 -7.481115  10/11/2019
# 6  -7.685743  -8.813491 -6.793098  22/11/2019
# 7  -7.974712  -8.990287 -6.993795  04/12/2019
# 8  -8.171959  -9.356175 -7.164786  16/12/2019
# 9  -8.568241  -9.655109 -7.574184  28/12/2019
# 10 -8.200825  -9.239112 -7.081237  09/01/2020
# 11 -8.008898  -8.922173 -6.938013  21/01/2020
# 12 -8.383687  -9.310959 -7.258154  02/02/2020
# 13 -7.707244  -8.812419 -6.909062  14/02/2020
# 14 -7.841531  -8.915773 -6.658035  26/02/2020
# 15 -7.622122  -8.759349 -6.797528  09/03/2020
# 16 -7.927097  -8.930521 -6.944872  21/03/2020
# 17 -8.025056  -8.962089 -7.026310  02/04/2020
# 18 -7.691808  -8.722047 -6.533518  14/04/2020
# ...

# %%
print('min =', df_VV['mediana'].min())
print('max =', df_VV['mediana'].max())
print('amplitude = ', df_VV['mediana'].max() - df_VV['mediana'].min())
# Out:
# min = -9.30611841078057
# max = -7.6221223031837635
# amplitude =  1.6839961075968066

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(df_VH.date, df_VH['mediana'], 'g', marker='o', label='Mediana')
ax.plot(df_VH.date, df_VH['Q75'], 'or', label='Percentil - 75%')
ax.plot(df_VH.date, df_VH['Q25'], 'ob', label='Percentil - 25%')

plt.xticks(rotation=60)

plt.ylim(-16.5, -12.0)
plt.legend()
ax.set_xlabel('Data')
ax.set_ylabel('Mediana [dB]')
"""
plt.savefig('C:/Users/jales/Desktop/SBSR_figures/FF/amostras_medianas_ff_vh.svg', dpi=None, facecolor='w', edgecolor='w',
        orientation='landscape', format='svg', transparent=False)
"""
# Out:
# "\nplt.savefig('C:/Users/jales/Desktop/SBSR_figures/FF/amostras_medianas_ff_vh.svg', dpi=None, facecolor='w', edgecolor='w',\n        orientation='landscape', format='svg', transparent=False)\n"

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(df_VH.date, df_VH['mediana'], 'g', marker='o', label='Mediana - VH')
ax.plot(df_VV.date, df_VV['mediana'], 'orange', marker='o', label='Mediana - VV')
ax.plot(df_VH.date, df_VH['Q75'], 'or', label='Percentil - 75%')
ax.plot(df_VH.date, df_VH['Q25'], 'ob', label='Percentil - 25%')


ax.plot(df_VV.date, df_VV['Q75'], 'or')
ax.plot(df_VV.date, df_VV['Q25'], 'ob')

plt.xticks(rotation=45)
plt.title('Formação Florestal')

#plt.ylim(-18.0, -12.0)
plt.legend()
ax.set_xlabel('Data')
ax.set_ylabel('Mediana [dB]')
'''
plt.savefig('C:/Users/jales/Desktop/SBSR_figures/FF/amostras_medianas_ff_vh_vv.svg', dpi=None, facecolor='w', edgecolor='w',
        orientation='landscape', format='svg', transparent=False)
'''
# Out:
# "\nplt.savefig('C:/Users/jales/Desktop/SBSR_figures/FF/amostras_medianas_ff_vh_vv.svg', dpi=None, facecolor='w', edgecolor='w',\n        orientation='landscape', format='svg', transparent=False)\n"
