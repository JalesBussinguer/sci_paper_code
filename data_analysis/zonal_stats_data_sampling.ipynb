# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dprvi = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDpRVI.csv')
prvi = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalPRVI.csv')
dpsvi = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDPSVI.csv')
dpsvim = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDPSVIm.csv')
rvi = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalRVI.csv')

# %%
dprvi
# Out:
#      Unnamed: 0      mean       std    median        date
# 0             0  0.540866  0.134692  0.537038  2021-12-29
# 1             0  0.536249  0.135689  0.531162  2021-12-05
# 2             0  0.544760  0.135834  0.540431  2021-11-23
# 3             0  0.558778  0.136294  0.555338  2021-11-11
# 4             0  0.534099  0.134317  0.529146  2021-10-30
# ..          ...       ...       ...       ...         ...
# 144           0  0.575047  0.136197  0.572599  2017-03-01
# 145           0  0.546416  0.134802  0.542077  2017-02-17
# 146           0  0.558617  0.135859  0.555105  2017-02-05
# 147           0  0.570596  0.135622  0.567525  2017-01-24
# 148           0  0.557324  0.134675  0.553504  2017-01-12
#
# [149 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(dprvi.date, dprvi['std'], 'g', marker='o')

plt.xticks(rotation=45)
ax.set_xlabel('Date')
