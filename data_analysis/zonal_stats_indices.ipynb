# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
dprvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDpRVI_reindex.csv')
dprvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaDpRVI_reindex.csv')
dprvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreDpRVI_reindex.csv')

prvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalPRVI_reindex.csv')
prvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaPRVI_reindex.csv')
prvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestrePRVI_reindex.csv')

dpsvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDPSVI_reindex.csv')
dpsvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaDPSVI_reindex.csv')
dpsvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreDPSVI_reindex.csv')

dpsvim_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDPSVIm_reindex.csv')
dpsvim_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaDPSVIm_reindex.csv')
dpsvim_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreDPSVIm_reindex.csv')

rvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalRVI_reindex.csv')
rvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaRVI_reindex.csv')
rvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreRVI_reindex.csv')

# %%
def month_season_detector(df):

    df['data'] = pd.to_datetime(df['date'], format='%Y/%m/%d')

    df['month'] = df['data'].dt.month

    df.loc[df['month']==1,'mes'] = 'Jan'
    df.loc[df['month']==2,'mes'] = 'Feb'
    df.loc[df['month']==3,'mes'] = 'Mar'
    df.loc[df['month']==4,'mes'] = 'Apr'
    df.loc[df['month']==5,'mes'] = 'May'
    df.loc[df['month']==6,'mes'] = 'Jun'
    df.loc[df['month']==7,'mes'] = 'Jul'
    df.loc[df['month']==8,'mes'] = 'Aug'
    df.loc[df['month']==9,'mes'] = 'Sep'
    df.loc[df['month']==10,'mes'] = 'Oct'
    df.loc[df['month']==11,'mes'] = 'Nov'
    df.loc[df['month']==12,'mes'] = 'Dec'

    df.loc[df['month']==1,'season'] = 'wet'
    df.loc[df['month']==2,'season'] = 'wet'
    df.loc[df['month']==3,'season'] = 'wet'
    df.loc[df['month']==4,'season'] = 'wet'
    df.loc[df['month']==5,'season'] = 'dry'
    df.loc[df['month']==6,'season'] = 'dry'
    df.loc[df['month']==7,'season'] = 'dry'
    df.loc[df['month']==8,'season'] = 'dry'
    df.loc[df['month']==9,'season'] = 'dry'
    df.loc[df['month']==10,'season'] = 'wet'
    df.loc[df['month']==11,'season'] = 'wet'
    df.loc[df['month']==12,'season'] = 'wet'

# %%
month_season_detector(dprvi_f)
month_season_detector(dprvi_s)
month_season_detector(dprvi_c)
month_season_detector(prvi_f)
month_season_detector(prvi_s)
month_season_detector(prvi_c)
month_season_detector(dpsvi_f)
month_season_detector(dpsvi_s)
month_season_detector(dpsvi_c)
month_season_detector(dpsvim_f)
month_season_detector(dpsvim_s)
month_season_detector(dpsvim_c)
month_season_detector(rvi_f)
month_season_detector(rvi_s)
month_season_detector(rvi_c)

# %%
red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

pink_patch = dict(facecolor='pink', color='k')
blue_patch = dict(facecolor='lightblue', color='k')
green_patch = dict(facecolor='lightgreen', color='k')
orange_patch = dict(facecolor='orange', color='k')
yellow_patch = dict(facecolor='yellow', color='k')

median_patch = dict(color='red')

# %%
dprvi_f_dict = {'wet': dprvi_f.loc[dprvi_f['season']=='wet']['median'].values, 'dry': dprvi_f.loc[dprvi_f['season']=='dry']['median'].values}
dprvi_s_dict = {'wet': dprvi_s.loc[dprvi_s['season']=='wet']['median'].values, 'dry': dprvi_s.loc[dprvi_s['season']=='dry']['median'].values}
dprvi_c_dict = {'wet': dprvi_c.loc[dprvi_c['season']=='wet']['median'].values, 'dry': dprvi_c.loc[dprvi_c['season']=='dry']['median'].values}

prvi_f_dict = {'wet': prvi_f.loc[prvi_f['season']=='wet']['median'].values, 'dry': prvi_f.loc[prvi_f['season']=='dry']['median'].values}
prvi_s_dict = {'wet': prvi_s.loc[prvi_s['season']=='wet']['median'].values, 'dry': prvi_s.loc[prvi_s['season']=='dry']['median'].values}
prvi_c_dict = {'wet': prvi_c.loc[prvi_c['season']=='wet']['median'].values, 'dry': prvi_c.loc[prvi_c['season']=='dry']['median'].values}

dpsvi_f_dict = {'wet': dpsvi_f.loc[dpsvi_f['season']=='wet']['median'].values, 'dry': dpsvi_f.loc[dpsvi_f['season']=='dry']['median'].values}
dpsvi_s_dict = {'wet': dpsvi_s.loc[dpsvi_s['season']=='wet']['median'].values, 'dry': dpsvi_s.loc[dpsvi_s['season']=='dry']['median'].values}
dpsvi_c_dict = {'wet': dpsvi_c.loc[dpsvi_c['season']=='wet']['median'].values, 'dry': dpsvi_c.loc[dpsvi_c['season']=='dry']['median'].values}

dpsvim_f_dict = {'wet': dpsvim_f.loc[dpsvim_f['season']=='wet']['median'].values, 'dry': dpsvim_f.loc[dpsvim_f['season']=='dry']['median'].values}
dpsvim_s_dict = {'wet': dpsvim_s.loc[dpsvim_s['season']=='wet']['median'].values, 'dry': dpsvim_s.loc[dpsvim_s['season']=='dry']['median'].values}
dpsvim_c_dict = {'wet': dpsvim_c.loc[dpsvim_c['season']=='wet']['median'].values, 'dry': dpsvim_c.loc[dpsvim_c['season']=='dry']['median'].values}

rvi_f_dict = {'wet': rvi_f.loc[rvi_f['season']=='wet']['median'].values, 'dry': rvi_f.loc[rvi_f['season']=='dry']['median'].values}
rvi_s_dict = {'wet': rvi_s.loc[rvi_s['season']=='wet']['median'].values, 'dry': rvi_s.loc[rvi_s['season']=='dry']['median'].values}
rvi_c_dict = {'wet': rvi_c.loc[rvi_c['season']=='wet']['median'].values, 'dry': rvi_c.loc[rvi_c['season']=='dry']['median'].values}

# %%
index = prvi_f_dict['dry']

q1 = np.quantile(index, 0.25)
q3 = np.quantile(index, 0.75)

iqr = q3 - q1

# %%
upper = q3+(1.5*iqr)
lower = q1-(1.5*iqr)

# %%
outliers = index[(index <= lower) | (index >= upper)]

# %%
outliers
# Out:
# array([0.00766805])

# %%
prvi_c.head(60)
# Out:
#         mean       std    median  percentile_25  percentile_75        date  \
# 0   0.005595  0.003347  0.004836       0.003199       0.007167  2017-01-12
# 1   0.008622  0.004511  0.007757       0.005328       0.011000  2017-01-24
# 2   0.006421  0.003573  0.005688       0.003835       0.008209  2017-02-05
# 3   0.005755  0.003125  0.005122       0.003484       0.007357  2017-02-17
# 4   0.009381  0.004908  0.008436       0.005795       0.011961  2017-03-01
# 5   0.004816  0.002633  0.004278       0.002919       0.006127  2017-03-13
# 6   0.006020  0.003296  0.005352       0.003642       0.007665  2017-03-25
# 7   0.006283  0.003342  0.005614       0.003863       0.007990  2017-04-06
# 8   0.004926  0.002686  0.004380       0.002984       0.006274  2017-04-18
# 9   0.007520  0.004218  0.006651       0.004466       0.009633  2017-04-30
# 10  0.004570  0.002534  0.004045       0.002746       0.005824  2017-05-12
# ...

# %%
rain = pd.read_csv('D:/thesis_data/pluviometric_data/pluviometric_data_PNB_paper_01.csv', sep=',')

# %%
month_season_detector(rain)

# %%
rain.head(50)
# Out:
#           date  gauge_mm       data  month  mes season
# 0   2017/01/12       0.0 2017-01-12      1  Jan    wet
# 1   2017/01/24       3.1 2017-01-24      1  Jan    wet
# 2   2017/02/05       0.3 2017-02-05      2  Feb    wet
# 3   2017/02/17       0.0 2017-02-17      2  Feb    wet
# 4   2017/03/01       3.1 2017-03-01      3  Mar    wet
# 5   2017/03/13       0.0 2017-03-13      3  Mar    wet
# 6   2017/03/25       0.0 2017-03-25      3  Mar    wet
# 7   2017/04/06       0.0 2017-04-06      4  Apr    wet
# 8   2017/04/18       0.0 2017-04-18      4  Apr    wet
# 9   2017/04/30       3.9 2017-04-30      4  Apr    wet
# 10  2017/05/12       0.0 2017-05-12      5  May    dry
# 11  2017/05/24       0.0 2017-05-24      5  May    dry
# 12  2017/06/05       0.0 2017-06-05      6  Jun    dry
# 13  2017/06/17       0.0 2017-06-17      6  Jun    dry
# 14  2017/06/29       0.0 2017-06-29      6  Jun    dry
# 15  2017/07/11       0.0 2017-07-11      7  Jul    dry
# ...

# %% [markdown]
# ## DpRVI

# %%
label_size = 20

fig, ax = plt.subplots(3, 2, figsize=(30, 10), gridspec_kw={'width_ratios': [25, 1]})

ax[0,0].vlines(dprvi_f.index[9], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[21], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[39], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[50], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[67], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[80], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[98], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[111], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[128], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[141], ymin=0, ymax=1.5, colors='k', linewidth=2)

ax[0,0].vlines(dprvi_f.index, ymin=dprvi_f['percentile_25'], ymax=dprvi_f['percentile_75'], colors='k', linewidth=2)
ax[0,0].plot(dprvi_f.index, dprvi_f['median'], 'limegreen', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[0,0].plot(dprvi_f.index, dprvi_f['percentile_25'], 'ok', marker='_')
ax[0,0].plot(dprvi_f.index, dprvi_f['percentile_75'], 'ok', marker='_')
ax[0,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0,0].set_xticks(ticks=dprvi_f.index)
ax[0,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,0].set_ylim([0.40, 0.68])
ax[0,0].set_xlim([-1, 149])
ax[0,0].set_ylabel('GF', fontsize=25)
ax[0,0].locator_params(axis='x', nbins=60)
ax[0,0].locator_params(axis='y', nbins=8)
ax[0,0].legend(fontsize=15, loc='upper left')

# standard deviation curve
sec_0 = ax[0,0].twinx()
sec_0.plot(dprvi_f.index, dprvi_f['std'], color='crimson', linewidth=3, label='std')
sec_0.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_0.set_ylabel('std', fontsize=20)
sec_0.locator_params(axis='y', nbins=8)
sec_0.legend(loc='upper right', fontsize=15)

ax[0,1].boxplot(dprvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=blue_patch, medianprops=median_patch)
ax[0,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,1].set_xticklabels(dprvi_f_dict.keys(), fontsize=15)
ax[0,1].set_ylim([0.49, 0.58])
ax[0,1].locator_params(axis='y', nbins=10)


# temporal series
ax[1,0].vlines(dprvi_s.index, ymin=dprvi_s['percentile_25'], ymax=dprvi_s['percentile_75'], colors='k', linewidth=2)
ax[1,0].plot(dprvi_s.index, dprvi_s['median'], 'orange', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[1,0].plot(dprvi_s.index, dprvi_s['percentile_25'], 'ok', marker='_')
ax[1,0].plot(dprvi_s.index, dprvi_s['percentile_75'], 'ok', marker='_')
ax[1,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,0].set_xticks(ticks=dprvi_s.index)
ax[1,0].set_ylim([0.40, 0.72])
ax[1,0].set_xlim([-1, 149])
ax[1,0].set_ylabel('SL', fontsize=25)
ax[1,0].locator_params(axis='x', nbins=60)
ax[1,0].locator_params(axis='y', nbins=8)
ax[1,0].legend(fontsize=15, loc='upper left')

# standard deviation curve
sec_0 = ax[1,0].twinx()
sec_0.plot(dprvi_s.index, dprvi_s['std'], color='crimson', linewidth=3, label='std')
sec_0.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_0.locator_params(axis='y', nbins=8)
sec_0.legend(loc='upper right', fontsize=15)

# boxplots
ax[1,1].boxplot(dprvi_s_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=blue_patch, medianprops=median_patch)
ax[1,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,1].set_xticklabels(dprvi_s_dict.keys(), fontsize=15)
ax[1,1].set_ylim([0.50, 0.62])
ax[1,1].locator_params(axis='y', nbins=10)


ax[2,0].vlines(dprvi_c.index, ymin=dprvi_c['percentile_25'], ymax=dprvi_c['percentile_75'], colors='k', linewidth=2)
ax[2,0].plot(dprvi_c.index, dprvi_c['median'], 'gold', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[2,0].plot(dprvi_c.index, dprvi_c['percentile_25'], 'ok', marker='_')
ax[2,0].plot(dprvi_c.index, dprvi_c['percentile_75'], 'ok', marker='_')
ax[2,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,0].set_xticks(ticks=rvi_s.index)
ax[2,0].set_ylim([0.40, 0.75])
ax[2,0].set_xlim([-1, 149])
ax[2,0].set_ylabel('GL', fontsize=25)
ax[2,0].locator_params(axis='x', nbins=60)
ax[2,0].locator_params(axis='y', nbins=8)
ax[2,0].legend(fontsize=15, loc='upper left')

ax[2,1].boxplot(dprvi_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=blue_patch, medianprops=median_patch)
ax[2,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,1].set_xticklabels(dprvi_c_dict.keys(), fontsize=15)
ax[2,1].set_ylim([0.50, 0.65])
ax[2,1].locator_params(axis='y', nbins=10)

sec_0 = ax[2,0].twinx()
sec_0.plot(dprvi_c.index, dprvi_c['std'], color='crimson', linewidth=3, label='std')
sec_0.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_0.locator_params(axis='y', nbins=8)
sec_0.legend(loc='upper right', fontsize=15)

# %% [markdown]
# ## PRVI

# %%
label_size = 20

fig, ax = plt.subplots(3, 2, figsize=(30, 10), gridspec_kw={'width_ratios': [25, 1]})

ax[0,0].vlines(prvi_f.index[9], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(prvi_f.index[21], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(prvi_f.index[39], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(prvi_f.index[50], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(prvi_f.index[67], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(prvi_f.index[80], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(prvi_f.index[98], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(prvi_f.index[111], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(prvi_f.index[128], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(prvi_f.index[141], ymin=0, ymax=1.5, colors='k', linewidth=2)

ax[0,0].vlines(prvi_f.index, ymin=prvi_f['percentile_25'], ymax=prvi_f['percentile_75'], colors='k', linewidth=2)
ax[0,0].plot(prvi_f.index, prvi_f['median'], 'limegreen', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[0,0].plot(prvi_f.index, prvi_f['percentile_25'], 'ok', marker='_')
ax[0,0].plot(prvi_f.index, prvi_f['percentile_75'], 'ok', marker='_')
ax[0,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0,0].set_xticks(ticks=rvi_f.index)
ax[0,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,0].set_ylim([0.003, 0.0132])
ax[0,0].set_xlim([-1, 149])
ax[0,0].set_ylabel('PRVI', fontsize=30)
ax[0,0].locator_params(axis='x', nbins=60)
ax[0,0].locator_params(axis='y', nbins=8)
ax[0,0].legend(fontsize=15, loc='upper left')

ax[0,1].boxplot(prvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=green_patch, medianprops=median_patch)
ax[0,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,1].set_xticklabels(prvi_f_dict.keys(), fontsize=15)
ax[0,1].set_ylim([0.005, 0.0095])
ax[0,1].locator_params(axis='y', nbins=10)

sec_1 = ax[0,0].twinx()
sec_1.plot(dprvi_f.index, prvi_f['std'], color='crimson', linewidth=3, label='std')
sec_1.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_1.set_ylabel('std', fontsize=20)
sec_1.set_ylim([0.0035, 0.006])
sec_1.locator_params(axis='y', nbins=8)
sec_1.legend(loc='upper right', fontsize=15)


# temporal profiles
ax[1,0].vlines(prvi_s.index, ymin=prvi_s['percentile_25'], ymax=prvi_s['percentile_75'], colors='k', linewidth=2)
ax[1,0].plot(prvi_s.index, prvi_s['median'], 'orange', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[1,0].plot(prvi_s.index, prvi_s['percentile_25'], 'ok', marker='_')
ax[1,0].plot(prvi_s.index, prvi_s['percentile_75'], 'ok', marker='_')
ax[1,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,0].set_xticks(ticks=rvi_s.index)
ax[1,0].set_ylim([0, 0.016])
ax[1,0].set_xlim([-1, 149])
ax[1,0].set_ylabel('PRVI', fontsize=30)
ax[1,0].locator_params(axis='x', nbins=60)
ax[1,0].locator_params(axis='y', nbins=8)
ax[1,0].legend(fontsize=15, loc='upper left')

# boxplots
ax[1,1].boxplot(prvi_s_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=green_patch, medianprops=median_patch)
ax[1,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,1].set_xticklabels(prvi_s_dict.keys(), fontsize=15)
ax[1,1].locator_params(axis='y', nbins=12)

# standard deviation curves
sec_1 = ax[1,0].twinx()
sec_1.plot(prvi_s.index, prvi_s['std'], color='crimson', linewidth=3, label='std')
sec_1.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_1.locator_params(axis='y', nbins=8)
sec_1.legend(loc='upper right', fontsize=15)


ax[2,0].vlines(prvi_c.index, ymin=prvi_c['percentile_25'], ymax=prvi_c['percentile_75'], colors='k', linewidth=2)
ax[2,0].plot(prvi_c.index, prvi_c['median'], 'gold', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[2,0].plot(prvi_c.index, prvi_c['percentile_25'], 'ok', marker='_')
ax[2,0].plot(prvi_c.index, prvi_c['percentile_75'], 'ok', marker='_')
ax[2,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,0].set_xticks(ticks=rvi_c.index)
ax[2,0].set_ylim([0, 0.016])
ax[2,0].set_xlim([-1, 149])
ax[2,0].set_ylabel('PRVI', fontsize=30)
ax[2,0].locator_params(axis='x', nbins=60)
ax[2,0].locator_params(axis='y', nbins=8)
ax[2,0].legend(fontsize=15, loc='upper left')

ax[2,1].boxplot(prvi_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=green_patch, medianprops=median_patch)
ax[2,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,1].set_xticklabels(prvi_c_dict.keys(), fontsize=15)
ax[2,1].set_ylim([0.002, 0.011])
ax[2,1].locator_params(axis='y', nbins=10)

sec_1 = ax[2,0].twinx()
sec_1.plot(prvi_c.index, prvi_c['std'], color='crimson', linewidth=3, label='std')
sec_1.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_1.locator_params(axis='y', nbins=8)
sec_1.legend(loc='upper right', fontsize=15)

# %% [markdown]
# ## DPSVI

# %%
label_size = 20

fig, ax = plt.subplots(3, 2, figsize=(30, 10), gridspec_kw={'width_ratios': [25, 1]})

ax[0,0].vlines(dpsvi_f.index[9], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvi_f.index[21], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvi_f.index[39], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvi_f.index[50], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvi_f.index[67], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvi_f.index[80], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvi_f.index[98], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvi_f.index[111], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvi_f.index[128], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvi_f.index[141], ymin=0, ymax=1.5, colors='k', linewidth=2)

ax[0,0].vlines(dpsvi_f.index, ymin=dpsvi_f['percentile_25'], ymax=dpsvi_f['percentile_75'], colors='k', linewidth=2)
ax[0,0].plot(dpsvi_f.index, dpsvi_f['median'], 'limegreen', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[0,0].plot(dpsvi_f.index, dpsvi_f['percentile_25'], 'ok', marker='_')
ax[0,0].plot(dpsvi_f.index, dpsvi_f['percentile_75'], 'ok', marker='_')
ax[0,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0,0].set_xticks(ticks=rvi_f.index)
ax[0,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,0].set_ylim([-0.1, 0.6])
ax[0,0].set_xlim([-1, 149])
ax[0,0].set_ylabel('GF', fontsize=25)
ax[0,0].locator_params(axis='x', nbins=60)
ax[0,0].locator_params(axis='y', nbins=8)
ax[0,0].legend(loc='upper left', fontsize=15)

ax[0,1].boxplot(dpsvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=pink_patch, medianprops=median_patch)
ax[0,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,1].set_xticklabels(prvi_f_dict.keys(), fontsize=15)
ax[0,1].set_ylim([0, 0.5])
ax[0,1].locator_params(axis='y', nbins=10)

sec_2 = ax[0,0].twinx()
sec_2.plot(dpsvi_f.index, dpsvi_f['std'], 'crimson', linewidth=3, label='std')
sec_2.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_2.set_ylabel('std', fontsize=20)
sec_2.locator_params(axis='y', nbins=12)
sec_2.set_ylim([0, 0.2])
sec_2.legend(loc='upper right', fontsize=15)


# temporal profiles
ax[1,0].vlines(dpsvi_s.index, ymin=dpsvi_s['percentile_25'], ymax=dpsvi_s['percentile_75'], colors='k', linewidth=2)
ax[1,0].plot(dpsvi_s.index, dpsvi_s['median'], 'orange', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[1,0].plot(dpsvi_s.index, dpsvi_s['percentile_25'], 'ok', marker='_')
ax[1,0].plot(dpsvi_s.index, dpsvi_s['percentile_75'], 'ok', marker='_')
ax[1,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,0].set_xticks(ticks=rvi_f.index)
ax[1,0].set_ylim([-0.1, 0.5])
ax[1,0].set_xlim([-1, 149])
ax[1,0].set_ylabel('SL', fontsize=25)
ax[1,0].locator_params(axis='x', nbins=60)
ax[1,0].locator_params(axis='y', nbins=8)
ax[1,0].legend(loc='upper left', fontsize=15)

# boxplots
ax[1,1].boxplot(dpsvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=pink_patch, medianprops=median_patch)
ax[1,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,1].set_xticklabels(prvi_f_dict.keys(), fontsize=15)
#ax[2,1].set_ylim([0, 0.20])
ax[1,1].locator_params(axis='y', nbins=10)

# standard deviation curves
sec_2 = ax[1,0].twinx()
sec_2.plot(dpsvi_s.index, dpsvi_s['std'], 'crimson', linewidth=3, label='std')
sec_2.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_2.locator_params(axis='y', nbins=12)
sec_2.legend(loc='upper right', fontsize=15)


ax[2,0].vlines(dpsvi_c.index, ymin=dpsvi_c['percentile_25'], ymax=dpsvi_c['percentile_75'], colors='k', linewidth=2)
ax[2,0].plot(dpsvi_c.index, dpsvi_c['median'], 'gold', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[2,0].plot(dpsvi_c.index, dpsvi_c['percentile_25'], 'ok', marker='_')
ax[2,0].plot(dpsvi_c.index, dpsvi_c['percentile_75'], 'ok', marker='_')
ax[2,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,0].set_xticks(ticks=rvi_c.index)
ax[2,0].set_ylim([-0.1, 0.5])
ax[2,0].set_xlim([-1, 149])
ax[2,0].set_ylabel('GL', fontsize=25)
ax[2,0].locator_params(axis='x', nbins=60)
ax[2,0].locator_params(axis='y', nbins=8)
ax[2,0].legend(loc='upper left', fontsize=15)

ax[2,1].boxplot(dpsvi_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=pink_patch, medianprops=median_patch)
ax[2,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,1].set_xticklabels(dpsvi_c_dict.keys(), fontsize=15)
# ax[2,1].set_ylim([0, 0.30])
ax[2,1].locator_params(axis='y', nbins=10)

sec_2 = ax[2,0].twinx()
sec_2.plot(dpsvi_c.index, dpsvi_c['std'], 'crimson', linewidth=3, label='std')
sec_2.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_2.locator_params(axis='y', nbins=12)
sec_2.legend(loc='upper right', fontsize=15)

# %% [markdown]
# ## DPSVIm

# %%
label_size = 20

fig, ax = plt.subplots(3, 2, figsize=(30, 10), gridspec_kw={'width_ratios': [25, 1]})

ax[0,0].vlines(dpsvim_f.index[9], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvim_f.index[21], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvim_f.index[39], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvim_f.index[50], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvim_f.index[67], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvim_f.index[80], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvim_f.index[98], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvim_f.index[111], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvim_f.index[128], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dpsvim_f.index[141], ymin=0, ymax=1.5, colors='k', linewidth=2)


ax[0,0].vlines(dpsvim_f.index, ymin=dpsvim_f['percentile_25'], ymax=dpsvim_f['percentile_75'], colors='k', linewidth=2)
ax[0,0].plot(dpsvim_f.index, dpsvim_f['median'], 'orange', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[0,0].plot(dpsvim_f.index, dpsvim_f['percentile_25'], 'ok', marker='_')
ax[0,0].plot(dpsvim_f.index, dpsvim_f['percentile_75'], 'ok', marker='_')
ax[0,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0,0].set_xticks(ticks=rvi_f.index)
ax[0,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,0].set_ylim([0.0, 0.05])
ax[0,0].set_xlim([-1, 149])
ax[0,0].set_ylabel('DPSVIm', fontsize=30)
ax[0,0].locator_params(axis='x', nbins=60)
ax[0,0].locator_params(axis='y', nbins=6)
ax[0,0].legend(loc='upper left', fontsize=15)

sec_3 = ax[0,0].twinx()
sec_3.plot(dpsvim_f.index, dpsvim_f['std'], 'crimson', linewidth=3, label='std')
sec_3.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_3.set_ylabel('std', fontsize=20)
sec_3.locator_params(axis='y', nbins=8)
sec_3.legend(loc='upper right', fontsize=15)
#sec_3.set_ylim([0.010, 0.026])

ax[0,1].boxplot(dpsvim_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=orange_patch, medianprops=median_patch)
ax[0,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,1].set_xticklabels(prvi_f_dict.keys(), fontsize=20)
ax[0,1].set_ylim([0.013, 0.03])
ax[0,1].locator_params(axis='y', nbins=10)


# temporal profiles
ax[1,0].vlines(dpsvim_s.index, ymin=dpsvim_s['percentile_25'], ymax=dpsvim_s['percentile_75'], colors='k', linewidth=2)
ax[1,0].plot(dpsvim_s.index, dpsvim_s['median'], 'orange', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[1,0].plot(dpsvim_s.index, dpsvim_s['percentile_25'], 'ok', marker='_')
ax[1,0].plot(dpsvim_s.index, dpsvim_s['percentile_75'], 'ok', marker='_')
ax[1,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,0].set_xticks(ticks=rvi_s.index)
ax[1,0].set_ylim([0, 0.04])
ax[1,0].set_xlim([-1, 149])
ax[1,0].set_ylabel('DPSVIm', fontsize=30)
ax[1,0].locator_params(axis='x', nbins=60)
ax[1,0].locator_params(axis='y', nbins=6)
ax[1,0].legend(loc='upper left', fontsize=15)

# boxplots
ax[1,1].boxplot(dpsvim_s_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=orange_patch, medianprops=median_patch)
ax[1,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,1].set_xticklabels(prvi_s_dict.keys(), fontsize=label_size)
ax[1,1].set_ylim([0.004, 0.027])
ax[1,1].locator_params(axis='y', nbins=10)

# standard deviation curves
sec_3 = ax[1,0].twinx()
sec_3.plot(dpsvim_s.index, dpsvim_s['std'], linewidth=3, label='std')
sec_3.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_3.locator_params(axis='y', nbins=8)
sec_3.legend(loc='upper right', fontsize=15)


ax[2,0].vlines(dpsvim_c.index, ymin=dpsvim_c['percentile_25'], ymax=dpsvim_c['percentile_75'], colors='k', linewidth=2)
ax[2,0].plot(dpsvim_c.index, dpsvim_c['median'], 'orange', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[2,0].plot(dpsvim_c.index, dpsvim_c['percentile_25'], 'ok', marker='_')
ax[2,0].plot(dpsvim_c.index, dpsvim_c['percentile_75'], 'ok', marker='_')
ax[2,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2,0].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[2,0].set_xticks(ticks=rvi_c.index)
ax[2,0].set_ylim([-0.005, 0.030])
ax[2,0].set_xlim([-1, 149])
ax[2,0].set_ylabel('DPSVIm', fontsize=30)
ax[2,0].locator_params(axis='x', nbins=60)
ax[2,0].locator_params(axis='y', nbins=6)
ax[2,0].legend(loc='upper left', fontsize=15)

ax[2,1].boxplot(dpsvim_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=orange_patch, medianprops=median_patch)
ax[2,1].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[2,1].set_xticklabels(dpsvim_c_dict.keys(), fontsize=20)
ax[2,1].set_ylim([0.0, 0.02])
ax[2,1].locator_params(axis='y', nbins=10)

sec_3 = ax[2,0].twinx()
sec_3.plot(dpsvim_c.index, dpsvim_c['std'], linewidth=3, label='std')
sec_3.tick_params(axis='y', length=5, width=1.5, labelsize=25)
sec_3.locator_params(axis='y', nbins=8)
sec_3.legend(loc='upper right', fontsize=15)

# %% [markdown]
# ## RVI

# %%
# Temporal profiles

label_size = 20

fig, ax = plt.subplots(3, 2, figsize=(30, 10), gridspec_kw={'width_ratios': [25, 1]})

ax[0,0].vlines(rvi_f.index[9], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(rvi_f.index[21], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(rvi_f.index[39], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(rvi_f.index[50], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(rvi_f.index[67], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(rvi_f.index[80], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(rvi_f.index[98], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(rvi_f.index[111], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(rvi_f.index[128], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(rvi_f.index[141], ymin=0, ymax=1.5, colors='k', linewidth=2)


ax[0,0].vlines(rvi_f.index, ymin=rvi_f['percentile_25'], ymax=rvi_f['percentile_75'], colors='k', linewidth=2)
ax[0,0].plot(rvi_f.index, rvi_f['median'], 'limegreen', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[0,0].plot(rvi_f.index, rvi_f['percentile_25'], 'ok', marker='_')
ax[0,0].plot(rvi_f.index, rvi_f['percentile_75'], 'ok', marker='_')
ax[0,0].tick_params(axis='x', which='both', bottom=True, labelbottom=False, length=8, width=2)
ax[0,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,0].set_ylim([0.6, 1.1])
ax[0,0].set_xlim([-1, 149])
ax[0,0].set_ylabel('GF', fontsize=25)
ax[0,0].locator_params(axis='y', nbins=8)
ax[0,0].set_xticks(ticks=rvi_f.index)
ax[0,0].locator_params(axis='x', nbins=60)
ax[0,0].legend(loc='upper left', fontsize=15)

ax[0,1].boxplot(rvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=yellow_patch, medianprops=median_patch)
ax[0,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,1].set_xticklabels(prvi_f_dict.keys(), fontsize=15)
ax[0,1].set_ylim([0.725, 0.925])
ax[0,1].locator_params(axis='y', nbins=10)

sec_4 = ax[0,0].twinx()
sec_4.plot(dpsvim_f.index, rvi_f['std'], 'crimson', linewidth=3, label='std')
sec_4.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_4.set_ylabel('std', fontsize=20)
sec_4.locator_params(axis='y', nbins=8)
sec_4.set_ylim([0.23, 0.265])
sec_4.legend(loc='upper right', fontsize=15)


# temporal profiles
ax[1,0].vlines(rvi_s.index, ymin=rvi_s['percentile_25'], ymax=rvi_s['percentile_75'], colors='k', linewidth=2)
ax[1,0].plot(rvi_s.index, rvi_s['median'], 'orange', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[1,0].plot(rvi_s.index, rvi_s['percentile_25'], 'ok', marker='_')
ax[1,0].plot(rvi_s.index, rvi_s['percentile_75'], 'ok', marker='_')
ax[1,0].tick_params(axis='x', which='both', bottom=True, labelbottom=False, length=8, width=2)
ax[1,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,0].set_ylim([0.6, 1.2])
ax[1,0].set_xlim([-1, 149])
ax[1,0].set_ylabel('SL', fontsize=25)
ax[1,0].locator_params(axis='y', nbins=8)
ax[1,0].set_xticks(ticks=rvi_s.index)
ax[1,0].locator_params(axis='x', nbins=60)
ax[1,0].legend(loc='upper left', fontsize=15)

# boxplots
ax[1,1].boxplot(rvi_s_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=yellow_patch, medianprops=median_patch)
ax[1,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,1].set_xticklabels(prvi_f_dict.keys(), fontsize=15)
ax[1,1].set_ylim([0.75, 1])
ax[1,1].locator_params(axis='y', nbins=12)

# standard deviation curves
sec_4 = ax[1,0].twinx()
sec_4.plot(rvi_s.index, rvi_s['std'], 'crimson', linewidth=3, label='std')
sec_4.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_4.locator_params(axis='y', nbins=8)
sec_4.legend(loc='upper right', fontsize=15)



ax[2,0].vlines(rvi_c.index, ymin=rvi_c['percentile_25'], ymax=rvi_c['percentile_75'], colors='k', linewidth=2)
ax[2,0].plot(rvi_c.index, rvi_c['median'], 'gold', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[2,0].plot(rvi_c.index, rvi_c['percentile_25'], 'ok', marker='_')
ax[2,0].plot(rvi_c.index, rvi_c['percentile_75'], 'ok', marker='_')
ax[2,0].tick_params(axis='x', which='both', bottom=True, labelbottom=True, length=8, width=2)
ax[2,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,0].set_xticks(ticks=rvi_c.index)
ax[2,0].set_ylim([0.6, 1.3])
ax[2,0].set_xlim([-1, 149])
ax[2,0].set_ylabel('GL', fontsize=25)
ax[2,0].locator_params(axis='y', nbins=8)
ax[2,0].set_xticks(ticks=rvi_c.index)
ax[2,0].set_xticklabels(labels=rvi_c['mes'], fontdict={'fontsize': 20, 'rotation': 45})
ax[2,0].locator_params(axis='x', nbins=60)
ax[2,0].legend(loc='upper left', fontsize=15)

ax[2,1].boxplot(rvi_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=yellow_patch, medianprops=median_patch)
ax[2,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,1].set_xticklabels(rvi_c_dict.keys(), fontsize=15)
ax[2,1].set_ylim([0.75, 1.10])
ax[2,1].locator_params(axis='y', nbins=10)

sec_4 = ax[2,0].twinx()
sec_4.plot(rvi_c.index, rvi_c['std'], 'crimson', linewidth=3, label='std')
sec_4.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_4.locator_params(axis='y', nbins=8)
sec_4.legend(loc='upper right', fontsize=15)

# %% [markdown]
# ## Florestal

# %%
# Temporal profiles

label_size = 20

fig, ax = plt.subplots(5, 2, figsize=(30, 15), gridspec_kw={'width_ratios': [25, 1]})

ax[0,0].vlines(dprvi_f.index[9], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[21], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[39], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[50], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[67], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[80], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[98], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[111], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[128], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_f.index[141], ymin=0, ymax=1.5, colors='k', linewidth=2)

# temporal series
ax[0,0].vlines(dprvi_f.index, ymin=dprvi_f['percentile_25'], ymax=dprvi_f['percentile_75'], colors='k', linewidth=2)
ax[0,0].plot(dprvi_f.index, dprvi_f['median'], 'dodgerblue', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[0,0].plot(dprvi_f.index, dprvi_f['percentile_25'], 'ok', marker='_')
ax[0,0].plot(dprvi_f.index, dprvi_f['percentile_75'], 'ok', marker='_')
ax[0,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0,0].set_xticks(ticks=rvi_f.index)
ax[0,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,0].set_ylim([0.40, 0.68])
ax[0,0].set_xlim([-1, 149])
ax[0,0].set_ylabel('DpRVI', fontsize=30)
ax[0,0].locator_params(axis='x', nbins=60)
ax[0,0].locator_params(axis='y', nbins=8)
ax[0,0].legend(fontsize=15, loc='upper left')

# standard deviation curve
sec_0 = ax[0,0].twinx()
sec_0.plot(dprvi_f.index, dprvi_f['std'], color='crimson', linewidth=3, label='std')
sec_0.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_0.set_ylabel('std', fontsize=20)
sec_0.locator_params(axis='y', nbins=8)
sec_0.legend(loc='upper right', fontsize=15)

ax[0,1].boxplot(dprvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=blue_patch, medianprops=median_patch)
ax[0,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
#ax[0,1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[0,1].set_xticklabels(dprvi_f_dict.keys(), fontsize=20)
ax[0,1].set_ylim([0.49, 0.58])
ax[0,1].locator_params(axis='y', nbins=10)


ax[1,0].vlines(prvi_f.index, ymin=prvi_f['percentile_25'], ymax=prvi_f['percentile_75'], colors='k', linewidth=2)
ax[1,0].plot(prvi_f.index, prvi_f['median'], 'limegreen', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[1,0].plot(prvi_f.index, prvi_f['percentile_25'], 'ok', marker='_')
ax[1,0].plot(prvi_f.index, prvi_f['percentile_75'], 'ok', marker='_')
ax[1,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1,0].set_xticks(ticks=rvi_f.index)
ax[1,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,0].set_ylim([0.003, 0.0132])
ax[1,0].set_xlim([-1, 149])
ax[1,0].set_ylabel('PRVI', fontsize=30)
ax[1,0].locator_params(axis='x', nbins=60)
ax[1,0].locator_params(axis='y', nbins=8)
ax[1,0].legend(fontsize=15, loc='upper left')

ax[1,1].boxplot(prvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=green_patch, medianprops=median_patch)
ax[1,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,1].set_xticklabels(prvi_f_dict.keys(), fontsize=20)
ax[1,1].set_ylim([0.005, 0.0095])
ax[1,1].locator_params(axis='y', nbins=10)

sec_1 = ax[1,0].twinx()
sec_1.plot(dprvi_f.index, prvi_f['std'], color='crimson', linewidth=3, label='std')
sec_1.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_1.set_ylabel('std', fontsize=20)
sec_1.set_ylim([0.0035, 0.006])
sec_1.locator_params(axis='y', nbins=8)
sec_1.legend(loc='upper right', fontsize=15)



ax[2,0].vlines(dpsvi_f.index, ymin=dpsvi_f['percentile_25'], ymax=dpsvi_f['percentile_75'], colors='k', linewidth=2)
ax[2,0].plot(dpsvi_f.index, dpsvi_f['median'], 'gold', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[2,0].plot(dpsvi_f.index, dpsvi_f['percentile_25'], 'ok', marker='_')
ax[2,0].plot(dpsvi_f.index, dpsvi_f['percentile_75'], 'ok', marker='_')
ax[2,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2,0].set_xticks(ticks=rvi_f.index)
ax[2,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,0].set_ylim([-0.1, 0.6])
ax[2,0].set_xlim([-1, 149])
ax[2,0].set_ylabel('DPSVI', fontsize=30)
ax[2,0].locator_params(axis='x', nbins=60)
ax[2,0].locator_params(axis='y', nbins=8)
ax[2,0].legend(loc='upper left', fontsize=15)

ax[2,1].boxplot(dpsvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=pink_patch, medianprops=median_patch)
ax[2,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,1].set_xticklabels(prvi_f_dict.keys(), fontsize=20)
ax[2,1].set_ylim([0, 0.5])
ax[2,1].locator_params(axis='y', nbins=10)

sec_2 = ax[2,0].twinx()
sec_2.plot(dpsvi_f.index, dpsvi_f['std'], 'crimson', linewidth=3, label='std')
sec_2.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_2.set_ylabel('std', fontsize=20)
sec_2.locator_params(axis='y', nbins=12)
sec_2.set_ylim([0, 0.2])
sec_2.legend(loc='upper right', fontsize=15)




ax[3,0].vlines(dpsvim_f.index, ymin=dpsvim_f['percentile_25'], ymax=dpsvim_f['percentile_75'], colors='k', linewidth=2)
ax[3,0].plot(dpsvim_f.index, dpsvim_f['median'], 'orange', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[3,0].plot(dpsvim_f.index, dpsvim_f['percentile_25'], 'ok', marker='_')
ax[3,0].plot(dpsvim_f.index, dpsvim_f['percentile_75'], 'ok', marker='_')
ax[3,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[3,0].set_xticks(ticks=rvi_f.index)
ax[3,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[3,0].set_ylim([0.0, 0.05])
ax[3,0].set_xlim([-1, 149])
ax[3,0].set_ylabel('DPSVIm', fontsize=30)
ax[3,0].locator_params(axis='x', nbins=60)
ax[3,0].locator_params(axis='y', nbins=6)
ax[3,0].legend(loc='upper left', fontsize=15)

sec_3 = ax[3,0].twinx()
sec_3.plot(dpsvim_f.index, dpsvim_f['std'], 'crimson', linewidth=3, label='std')
sec_3.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_3.set_ylabel('std', fontsize=20)
sec_3.locator_params(axis='y', nbins=8)
sec_3.legend(loc='upper right', fontsize=15)
#sec_3.set_ylim([0.010, 0.026])

ax[3,1].boxplot(dpsvim_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=orange_patch, medianprops=median_patch)
ax[3,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[3,1].set_xticklabels(prvi_f_dict.keys(), fontsize=20)
ax[3,1].set_ylim([0.013, 0.03])
ax[3,1].locator_params(axis='y', nbins=10)



ax[4,0].vlines(rvi_f.index, ymin=rvi_f['percentile_25'], ymax=rvi_f['percentile_75'], colors='k', linewidth=2)
ax[4,0].plot(rvi_f.index, rvi_f['median'], 'mediumorchid', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[4,0].plot(rvi_f.index, rvi_f['percentile_25'], 'ok', marker='_')
ax[4,0].plot(rvi_f.index, rvi_f['percentile_75'], 'ok', marker='_')
ax[4,0].tick_params(axis='x', which='both', bottom=True, labelbottom=True, length=8, width=2)
ax[4,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[4,0].set_ylim([0.6, 1.1])
ax[4,0].set_xlim([-1, 149])
ax[4,0].set_ylabel('RVI', fontsize=30)
ax[4,0].locator_params(axis='y', nbins=8)
ax[4,0].set_xticks(ticks=rvi_f.index)
ax[4,0].set_xticklabels(labels=rvi_f['mes'], fontdict={'fontsize': 20, 'rotation':45})
ax[4,0].locator_params(axis='x', nbins=60)
ax[4,0].legend(loc='upper left', fontsize=15)

ax[4,1].boxplot(rvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=yellow_patch, medianprops=median_patch)
ax[4,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[4,1].set_xticklabels(prvi_f_dict.keys(), fontsize=20)
ax[4,1].set_ylim([0.725, 0.925])
ax[4,1].locator_params(axis='y', nbins=10)

sec_4 = ax[4,0].twinx()
sec_4.plot(dpsvim_f.index, rvi_f['std'], 'crimson', linewidth=3, label='std')
sec_4.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_4.set_ylabel('std', fontsize=20)
sec_4.locator_params(axis='y', nbins=8)
sec_4.set_ylim([0.23, 0.265])
sec_4.legend(loc='upper right', fontsize=15)

plt.tight_layout()

# plt.savefig('C:/Users/jales/Desktop/ff_profiles_rain_test_def.svg', dpi=None, facecolor='w', edgecolor='w',
#     orientation='landscape', format='svg', transparent=False)

# %% [markdown]
# ## Savanica

# %%
# Temporal profiles

fig, ax = plt.subplots(5, 2, figsize=(30, 15), gridspec_kw={'width_ratios': [25, 1]})

# Seasonal vlines
ax[0,0].vlines(dprvi_s.index[9], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_s.index[21], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_s.index[39], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_s.index[50], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_s.index[67], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_s.index[80], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_s.index[98], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_s.index[111], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_s.index[128], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_s.index[141], ymin=0, ymax=1.5, colors='k', linewidth=2)

# temporal series
ax[0,0].vlines(dprvi_s.index, ymin=dprvi_s['percentile_25'], ymax=dprvi_s['percentile_75'], colors='k', linewidth=2)
ax[0,0].plot(dprvi_s.index, dprvi_s['median'], 'dodgerblue', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[0,0].plot(dprvi_s.index, dprvi_s['percentile_25'], 'ok', marker='_')
ax[0,0].plot(dprvi_s.index, dprvi_s['percentile_75'], 'ok', marker='_')
ax[0,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,0].set_xticks(ticks=rvi_f.index)
ax[0,0].set_ylim([0.40, 0.72])
ax[0,0].set_xlim([-1, 149])
ax[0,0].set_ylabel('DpRVI', fontsize=30)
ax[0,0].locator_params(axis='x', nbins=60)
ax[0,0].locator_params(axis='y', nbins=8)
ax[0,0].legend(fontsize=15, loc='upper left')

# standard deviation curve
sec_0 = ax[0,0].twinx()
sec_0.plot(dprvi_s.index, dprvi_s['std'], color='crimson', linewidth=3, label='std')
sec_0.tick_params(axis='y', length=5, width=1.5, labelsize=25)
sec_0.locator_params(axis='y', nbins=8)
sec_0.legend(loc='upper right', fontsize=15)

# boxplots
ax[0,1].boxplot(dprvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=blue_patch, medianprops=median_patch)
ax[0,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[0,1].set_xticklabels(dprvi_f_dict.keys(), fontsize=label_size)
ax[0,1].set_ylim([0.49, 0.58])
ax[0,1].locator_params(axis='y', nbins=10)




# temporal profiles
ax[1,0].vlines(prvi_s.index, ymin=prvi_s['percentile_25'], ymax=prvi_s['percentile_75'], colors='k', linewidth=2)
ax[1,0].plot(prvi_s.index, prvi_s['median'], 'limegreen', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[1,0].plot(prvi_s.index, prvi_s['percentile_25'], 'ok', marker='_')
ax[1,0].plot(prvi_s.index, prvi_s['percentile_75'], 'ok', marker='_')
ax[1,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,0].set_xticks(ticks=rvi_s.index)
ax[1,0].set_ylim([0, 0.016])
ax[1,0].set_xlim([-1, 149])
ax[1,0].set_ylabel('PRVI', fontsize=30)
ax[1,0].locator_params(axis='x', nbins=60)
ax[1,0].locator_params(axis='y', nbins=8)
ax[1,0].legend(fontsize=15, loc='upper left')

# boxplots
ax[1,1].boxplot(prvi_s_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=green_patch, medianprops=median_patch)
ax[1,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[1,1].set_xticklabels(prvi_s_dict.keys(), fontsize=label_size)
ax[1,1].set_ylim([0.003, 0.011])
ax[1,1].locator_params(axis='y', nbins=12)

# standard deviation curves
sec_1 = ax[1,0].twinx()
sec_1.plot(prvi_s.index, prvi_s['std'], color='crimson', linewidth=3, label='std')
sec_1.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_1.locator_params(axis='y', nbins=8)
sec_1.legend(loc='upper right', fontsize=15)


# temporal profiles
ax[2,0].vlines(dpsvi_s.index, ymin=dpsvi_s['percentile_25'], ymax=dpsvi_s['percentile_75'], colors='k', linewidth=2)
ax[2,0].plot(dpsvi_s.index, dpsvi_s['median'], 'r', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[2,0].plot(dpsvi_s.index, dpsvi_s['percentile_25'], 'ok', marker='_')
ax[2,0].plot(dpsvi_s.index, dpsvi_s['percentile_75'], 'ok', marker='_')
ax[2,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,0].set_xticks(ticks=rvi_f.index)
ax[2,0].set_ylim([-0.1, 0.5])
ax[2,0].set_xlim([-1, 149])
ax[2,0].set_ylabel('DPSVI', fontsize=30)
ax[2,0].locator_params(axis='x', nbins=60)
ax[2,0].locator_params(axis='y', nbins=8)
ax[2,0].legend(loc='upper left', fontsize=15)

# boxplots
ax[2,1].boxplot(dpsvi_f_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=pink_patch, medianprops=median_patch)
ax[2,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[2,1].set_xticklabels(prvi_f_dict.keys(), fontsize=label_size)
#ax[2,1].set_ylim([0, 0.20])
ax[2,1].locator_params(axis='y', nbins=10)

# standard deviation curves
sec_2 = ax[2,0].twinx()
sec_2.plot(dpsvi_s.index, dpsvi_s['std'], linewidth=3, label='std')
sec_2.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_2.locator_params(axis='y', nbins=12)
sec_2.legend(loc='upper right', fontsize=15)


# temporal profiles
ax[3,0].vlines(dpsvim_s.index, ymin=dpsvim_s['percentile_25'], ymax=dpsvim_s['percentile_75'], colors='k', linewidth=2)
ax[3,0].plot(dpsvim_s.index, dpsvim_s['median'], 'orange', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[3,0].plot(dpsvim_s.index, dpsvim_s['percentile_25'], 'ok', marker='_')
ax[3,0].plot(dpsvim_s.index, dpsvim_s['percentile_75'], 'ok', marker='_')
ax[3,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[3,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[3,0].set_xticks(ticks=rvi_s.index)
ax[3,0].set_ylim([0, 0.04])
ax[3,0].set_xlim([-1, 149])
ax[3,0].set_ylabel('DPSVIm', fontsize=30)
ax[3,0].locator_params(axis='x', nbins=60)
ax[3,0].locator_params(axis='y', nbins=6)
ax[3,0].legend(loc='upper left', fontsize=15)

# boxplots
ax[3,1].boxplot(dpsvim_s_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=orange_patch, medianprops=median_patch)
ax[3,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[3,1].set_xticklabels(prvi_s_dict.keys(), fontsize=label_size)
ax[3,1].set_ylim([0.004, 0.027])
ax[3,1].locator_params(axis='y', nbins=10)

# standard deviation curves
sec_3 = ax[3,0].twinx()
sec_3.plot(dpsvim_s.index, dpsvim_s['std'], linewidth=3, label='std')
sec_3.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_3.locator_params(axis='y', nbins=8)
sec_3.legend(loc='upper right', fontsize=15)

# temporal profiles
ax[4,0].vlines(rvi_s.index, ymin=rvi_s['percentile_25'], ymax=rvi_s['percentile_75'], colors='k', linewidth=2)
ax[4,0].plot(rvi_s.index, rvi_s['median'], 'gold', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[4,0].plot(rvi_s.index, rvi_s['percentile_25'], 'ok', marker='_')
ax[4,0].plot(rvi_s.index, rvi_s['percentile_75'], 'ok', marker='_')
ax[4,0].tick_params(axis='x', which='both', bottom=True, labelbottom=True, length=8, width=2)
ax[4,0].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[4,0].set_ylim([0.6, 1.2])
ax[4,0].set_xlim([-1, 149])
ax[4,0].set_ylabel('RVI', fontsize=30)
ax[4,0].locator_params(axis='y', nbins=8)
ax[4,0].set_xticks(ticks=rvi_s.index)
ax[4,0].set_xticklabels(labels=rvi_s['mes'], fontdict={'fontsize': 25, 'rotation': 45})
ax[4,0].locator_params(axis='x', nbins=60)
ax[4,0].legend(loc='upper left', fontsize=15)

# boxplots
ax[4,1].boxplot(rvi_s_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=yellow_patch, medianprops=median_patch)
ax[4,1].tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
ax[4,1].set_xticklabels(prvi_f_dict.keys(), fontsize=label_size)
ax[4,1].set_ylim([0.75, 1])
ax[4,1].locator_params(axis='y', nbins=12)

# standard deviation curves
sec_4 = ax[4,0].twinx()
sec_4.plot(rvi_s.index, rvi_s['std'], linewidth=3, label='std')
sec_4.tick_params(axis='y', length=5, width=1.5, labelsize=label_size)
sec_4.locator_params(axis='y', nbins=8)
sec_4.legend(loc='upper right', fontsize=15)

plt.tight_layout()

# plt.savefig('C:/Users/jales/Desktop/fs_time_series.svg', dpi=None, facecolor='w', edgecolor='w',
#          orientation='landscape', format='svg', transparent=False)

# %% [markdown]
# ##  Campestre

# %%
# Temporal profiles

fig, ax = plt.subplots(5, 2, figsize=(30, 20), gridspec_kw={'width_ratios': [20, 1]})


ax[0,0].vlines(dprvi_c.index[9], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_c.index[21], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_c.index[39], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_c.index[50], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_c.index[67], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_c.index[80], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_c.index[98], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_c.index[111], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_c.index[128], ymin=0, ymax=1.5, colors='k', linewidth=2)
ax[0,0].vlines(dprvi_c.index[141], ymin=0, ymax=1.5, colors='k', linewidth=2)


ax[0,0].vlines(dprvi_c.index, ymin=dprvi_c['percentile_25'], ymax=dprvi_c['percentile_75'], colors='k', linewidth=2)
ax[0,0].plot(dprvi_c.index, dprvi_c['median'], 'dodgerblue', marker='o', markersize=9, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[0,0].plot(dprvi_c.index, dprvi_c['percentile_25'], 'ok', marker='_')
ax[0,0].plot(dprvi_c.index, dprvi_c['percentile_75'], 'ok', marker='_')
ax[0,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0,0].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[0,0].set_xticks(ticks=rvi_s.index)
ax[0,0].set_ylim([0.40, 0.75])
ax[0,0].set_xlim([-1, 149])
ax[0,0].set_ylabel('DpRVI', fontsize=30)
ax[0,0].locator_params(axis='x', nbins=60)
ax[0,0].locator_params(axis='y', nbins=8)
ax[0,0].legend(fontsize=15, loc='upper left')

ax[0,1].boxplot(dprvi_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=blue_patch, medianprops=median_patch)
ax[0,1].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[0,1].set_xticklabels(dprvi_c_dict.keys(), fontsize=20)
ax[0,1].set_ylim([0.50, 0.65])
ax[0,1].locator_params(axis='y', nbins=10)

sec_0 = ax[0,0].twinx()
sec_0.plot(dprvi_c.index, dprvi_c['std'], color='crimson', linewidth=3, label='std')
sec_0.tick_params(axis='y', length=5, width=1.5, labelsize=25)
sec_0.locator_params(axis='y', nbins=8)
sec_0.legend(loc='upper right', fontsize=15)

ax[1,0].vlines(prvi_c.index, ymin=prvi_c['percentile_25'], ymax=prvi_c['percentile_75'], colors='k', linewidth=2)
ax[1,0].plot(prvi_c.index, prvi_c['median'], 'g', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[1,0].plot(prvi_c.index, prvi_c['percentile_25'], 'ok', marker='_')
ax[1,0].plot(prvi_c.index, prvi_c['percentile_75'], 'ok', marker='_')
ax[1,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1,0].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[1,0].set_xticks(ticks=rvi_c.index)
ax[1,0].set_ylim([0, 0.016])
ax[1,0].set_xlim([-1, 149])
ax[1,0].set_ylabel('PRVI', fontsize=30)
ax[1,0].locator_params(axis='x', nbins=60)
ax[1,0].locator_params(axis='y', nbins=8)
ax[1,0].legend(fontsize=15, loc='upper left')

ax[1,1].boxplot(prvi_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=green_patch, medianprops=median_patch)
ax[1,1].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[1,1].set_xticklabels(prvi_c_dict.keys(), fontsize=20)
ax[1,1].set_ylim([0.002, 0.011])
ax[1,1].locator_params(axis='y', nbins=10)

sec_1 = ax[1,0].twinx()
sec_1.plot(prvi_c.index, prvi_c['std'], color='crimson', linewidth=3, label='std')
sec_1.tick_params(axis='y', length=5, width=1.5, labelsize=25)
sec_1.locator_params(axis='y', nbins=8)
sec_1.legend(loc='upper right', fontsize=15)


ax[2,0].vlines(dpsvi_c.index, ymin=dpsvi_c['percentile_25'], ymax=dpsvi_c['percentile_75'], colors='k', linewidth=2)
ax[2,0].plot(dpsvi_c.index, dpsvi_c['median'], 'r', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[2,0].plot(dpsvi_c.index, dpsvi_c['percentile_25'], 'ok', marker='_')
ax[2,0].plot(dpsvi_c.index, dpsvi_c['percentile_75'], 'ok', marker='_')
ax[2,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2,0].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[2,0].set_xticks(ticks=rvi_c.index)
ax[2,0].set_ylim([-0.1, 0.5])
ax[2,0].set_xlim([-1, 149])
ax[2,0].set_ylabel('DPSVI', fontsize=30)
ax[2,0].locator_params(axis='x', nbins=60)
ax[2,0].locator_params(axis='y', nbins=8)
ax[2,0].legend(loc='upper left', fontsize=15)

ax[2,1].boxplot(dpsvi_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=pink_patch, medianprops=median_patch)
ax[2,1].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[2,1].set_xticklabels(dpsvi_c_dict.keys(), fontsize=20)
# ax[2,1].set_ylim([0, 0.30])
ax[2,1].locator_params(axis='y', nbins=10)

sec_2 = ax[2,0].twinx()
sec_2.plot(dpsvi_c.index, dpsvi_c['std'], linewidth=3, label='std')
sec_2.tick_params(axis='y', length=5, width=1.5, labelsize=25)
sec_2.locator_params(axis='y', nbins=12)
sec_2.legend(loc='upper right', fontsize=15)


ax[3,0].vlines(dpsvim_c.index, ymin=dpsvim_c['percentile_25'], ymax=dpsvim_c['percentile_75'], colors='k', linewidth=2)
ax[3,0].plot(dpsvim_c.index, dpsvim_c['median'], 'orange', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[3,0].plot(dpsvim_c.index, dpsvim_c['percentile_25'], 'ok', marker='_')
ax[3,0].plot(dpsvim_c.index, dpsvim_c['percentile_75'], 'ok', marker='_')
ax[3,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[3,0].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[3,0].set_xticks(ticks=rvi_c.index)
ax[3,0].set_ylim([-0.005, 0.030])
ax[3,0].set_xlim([-1, 149])
ax[3,0].set_ylabel('DPSVIm', fontsize=30)
ax[3,0].locator_params(axis='x', nbins=60)
ax[3,0].locator_params(axis='y', nbins=6)
ax[3,0].legend(loc='upper left', fontsize=15)

ax[3,1].boxplot(dpsvim_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=orange_patch, medianprops=median_patch)
ax[3,1].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[3,1].set_xticklabels(dpsvim_c_dict.keys(), fontsize=20)
ax[3,1].set_ylim([0.0, 0.02])
ax[3,1].locator_params(axis='y', nbins=10)

sec_3 = ax[3,0].twinx()
sec_3.plot(dpsvim_c.index, dpsvim_c['std'], linewidth=3, label='std')
sec_3.tick_params(axis='y', length=5, width=1.5, labelsize=25)
sec_3.locator_params(axis='y', nbins=8)
sec_3.legend(loc='upper right', fontsize=15)


ax[4,0].vlines(rvi_c.index, ymin=rvi_c['percentile_25'], ymax=rvi_c['percentile_75'], colors='k', linewidth=2)
ax[4,0].plot(rvi_c.index, rvi_c['median'], 'yellow', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k', linewidth=3, label='median')
ax[4,0].plot(rvi_c.index, rvi_c['percentile_25'], 'ok', marker='_')
ax[4,0].plot(rvi_c.index, rvi_c['percentile_75'], 'ok', marker='_')
ax[4,0].tick_params(axis='x', which='both', bottom=True, labelbottom=True, length=8, width=2)
ax[4,0].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[4,0].set_xticks(ticks=rvi_c.index)
ax[4,0].set_ylim([0.6, 1.3])
ax[4,0].set_xlim([-1, 149])
ax[4,0].set_ylabel('RVI', fontsize=30)
ax[4,0].locator_params(axis='y', nbins=8)
ax[4,0].set_xticks(ticks=rvi_c.index)
ax[4,0].set_xticklabels(labels=rvi_c['mes'], fontdict={'fontsize': 20, 'rotation': 45})
ax[4,0].locator_params(axis='x', nbins=60)
ax[4,0].legend(loc='upper left', fontsize=15)

ax[4,1].boxplot(rvi_c_dict.values(), patch_artist=True, flierprops=red_circle, boxprops=yellow_patch, medianprops=median_patch)
ax[4,1].tick_params(axis='y', length=5, width=1.5, labelsize=25)
ax[4,1].set_xticklabels(rvi_c_dict.keys(), fontsize=20)
ax[4,1].set_ylim([0.75, 1.10])
ax[4,1].locator_params(axis='y', nbins=10)

sec_4 = ax[4,0].twinx()
sec_4.plot(rvi_c.index, rvi_c['std'], linewidth=3, label='std')
sec_4.tick_params(axis='y', length=5, width=1.5, labelsize=25)
sec_4.locator_params(axis='y', nbins=8)
sec_4.legend(loc='upper right', fontsize=15)


plt.tight_layout()

# plt.savefig('C:/Users/jales/Desktop/fc_time_series_ok.svg', dpi=None, facecolor='w', edgecolor='w',
#         orientation='landscape', format='svg', transparent=False)

# %% [markdown]
# ## Relation between mean and standard deviation

# %%
ff_rates = pd.read_csv('D:/thesis_data/VEG_INDICES/rates/FF_rates.csv')
fs_rates = pd.read_csv('D:/thesis_data/VEG_INDICES/rates/FS_rates.csv')
fc_rates = pd.read_csv('D:/thesis_data/VEG_INDICES/rates/FC_rates.csv')

# %%
ff_rates

# %%
dprvi_f['std']

# %%
fig, ax = plt.subplots(3, 2, figsize=(15, 12))

ax[0,0].scatter(ff_rates['dprvi'], dprvi_f['std'], color='blue')
ax[0,0].scatter(fs_rates['dprvi'], dprvi_s['std'], color='green')
ax[0,0].scatter(fc_rates['dprvi'], dprvi_c['std'], color='red')
ax[0,0].set_title('DpRVI')

ax[0,1].scatter(ff_rates['prvi'], prvi_f['std'], color='blue')
ax[0,1].scatter(fs_rates['prvi'], prvi_s['std'], color='green')
ax[0,1].scatter(fc_rates['prvi'], prvi_c['std'], color='red')
ax[0,1].set_title('PRVI')

ax[1,0].scatter(ff_rates['dpsvi'], dpsvi_f['std'], color='blue')
ax[1,0].scatter(fs_rates['dpsvi'], dpsvi_s['std'], color='green')
ax[1,0].scatter(fc_rates['dpsvi'], dpsvi_c['std'], color='red')
ax[1,0].set_title('DPSVI')

ax[1,1].scatter(ff_rates['dpsvim'], dpsvim_f['std'], color='blue')
ax[1,1].scatter(fs_rates['dpsvim'], dpsvim_s['std'], color='green')
ax[1,1].scatter(fc_rates['dpsvim'], dpsvim_c['std'], color='red')
ax[1,1].set_title('DPSVIm')

ax[2,0].scatter(ff_rates['rvi'], rvi_f['std'], color='blue')
ax[2,0].scatter(fs_rates['rvi'], rvi_s['std'], color='green')
ax[2,0].scatter(fc_rates['rvi'], rvi_c['std'], color='red')
ax[2,0].set_title('RVI')

# %%
import scipy.stats as sp
import numpy as np

ff_dprvi_linreg = sp.stats.linregress(dprvi_f['median'], dprvi_f['std'])
ff_dprvi_linreg_predict_y = ff_dprvi_linreg.intercept + ff_dprvi_linreg.slope * dprvi_f['median']

fs_dprvi_linreg = sp.stats.linregress(dprvi_s['median'], dprvi_s['std'])
fs_dprvi_linreg_predict_y = fs_dprvi_linreg.intercept + fs_dprvi_linreg.slope * dprvi_s['median']

fc_dprvi_linreg = sp.stats.linregress(dprvi_c['median'], dprvi_c['std'])
fc_dprvi_linreg_predict_y = fc_dprvi_linreg.intercept + fc_dprvi_linreg.slope * dprvi_c['median']


ff_prvi_linreg = sp.stats.linregress(prvi_f['median'], prvi_f['std'])
ff_prvi_linreg_predict_y = ff_prvi_linreg.intercept + ff_prvi_linreg.slope * prvi_f['median']

fs_prvi_linreg = sp.stats.linregress(prvi_s['median'], prvi_s['std'])
fs_prvi_linreg_predict_y = fs_prvi_linreg.intercept + fs_prvi_linreg.slope * prvi_s['median']

fc_prvi_linreg = sp.stats.linregress(prvi_c['median'], prvi_c['std'])
fc_prvi_linreg_predict_y = fc_prvi_linreg.intercept + fc_prvi_linreg.slope * prvi_c['median']


ff_dpsvi_linreg = sp.stats.linregress(dpsvi_f['median'], dpsvi_f['std'])
ff_dpsvi_linreg_predict_y = ff_dpsvi_linreg.intercept + ff_dpsvi_linreg.slope * dpsvi_f['median']

fs_dpsvi_linreg = sp.stats.linregress(dpsvi_s['median'], dpsvi_s['std'])
fs_dpsvi_linreg_predict_y = fs_dpsvi_linreg.intercept + fs_dpsvi_linreg.slope * dpsvi_s['median']

fc_dpsvi_linreg = sp.stats.linregress(dpsvi_c['median'], dpsvi_c['std'])
fc_dpsvi_linreg_predict_y = fc_dpsvi_linreg.intercept + fc_dpsvi_linreg.slope * dpsvi_c['median']


ff_dpsvim_linreg = sp.stats.linregress(dpsvim_f['median'], dpsvim_f['std'])
ff_dpsvim_linreg_predict_y = ff_dpsvim_linreg.intercept + ff_dpsvim_linreg.slope * dpsvim_f['median']

fs_dpsvim_linreg = sp.stats.linregress(dpsvim_s['median'], dpsvim_s['std'])
fs_dpsvim_linreg_predict_y = fs_dpsvim_linreg.intercept + fs_dpsvim_linreg.slope * dpsvim_s['median']

fc_dpsvim_linreg = sp.stats.linregress(dpsvim_c['median'], dpsvim_c['std'])
fc_dpsvim_linreg_predict_y = fc_dpsvim_linreg.intercept + fc_dpsvim_linreg.slope * dpsvim_c['median']


ff_rvi_linreg = sp.stats.linregress(rvi_f['median'], rvi_f['std'])
ff_rvi_linreg_predict_y = ff_rvi_linreg.intercept + ff_rvi_linreg.slope * rvi_f['median']

fs_rvi_linreg = sp.stats.linregress(rvi_s['median'], rvi_s['std'])
fs_rvi_linreg_predict_y = fs_rvi_linreg.intercept + fs_rvi_linreg.slope * rvi_s['median']

fc_rvi_linreg = sp.stats.linregress(rvi_c['median'], rvi_c['std'])
fc_rvi_linreg_predict_y = fc_rvi_linreg.intercept + fc_rvi_linreg.slope * rvi_c['median']

# %%
fig, ax = plt.subplots(3,5, figsize=(30, 10))

ax[0,0].set_title('DpRVI', fontsize=25)
ax[0,0].scatter(dprvi_f['median'], dprvi_f['std'], color='dodgerblue')
ax[0,0].plot(dprvi_f['median'], ff_dprvi_linreg_predict_y, 'r-')
ax[0,0].text(0.54, 0.133, f'r-squared = {round(ff_dprvi_linreg.rvalue, 2)}')
ax[0,0].set_ylabel('std', fontsize=15)
ax[0,0].locator_params(axis='x', nbins=8)

ax[1,0].scatter(dprvi_s['median'], dprvi_s['std'], color='limegreen')
ax[1,0].plot(dprvi_s['median'], fs_dprvi_linreg_predict_y, 'r-')
ax[1,0].text(0.55, 0.133, f'r-squared = {round(fs_dprvi_linreg.rvalue, 2)}')
ax[1,0].set_ylabel('std', fontsize=15)
ax[1,0].locator_params(axis='x', nbins=8)

ax[2,0].scatter(dprvi_c['median'], dprvi_c['std'], color='pink')
ax[2,0].plot(dprvi_c['median'], fc_dprvi_linreg_predict_y, 'r-')
ax[2,0].text(0.55, 0.133, f'r-squared = {round(fc_dprvi_linreg.rvalue, 2)}')
ax[2,0].set_xlabel('median', fontsize=15)
ax[2,0].set_ylabel('std', fontsize=15)
ax[2,0].locator_params(axis='x', nbins=10)

ax[0,1].set_title('PRVI', fontsize=25)
ax[0,1].scatter(prvi_f['median'], prvi_f['std'], color='dodgerblue')
ax[0,1].plot(prvi_f['median'], ff_prvi_linreg_predict_y, 'r-')
ax[0,1].text(0.0075,0.00375, f'r-squared = {round(ff_prvi_linreg.rvalue, 2)}')
ax[0,1].locator_params(axis='x', nbins=10)

ax[1,1].scatter(prvi_s['median'], prvi_s['std'], color='limegreen')
ax[1,1].plot(prvi_s['median'], fs_prvi_linreg_predict_y, 'r-')
ax[1,1].text(0.0075,0.00375, f'r-squared = {round(fs_prvi_linreg.rvalue, 2)}')
ax[1,1].locator_params(axis='x', nbins=10)

ax[2,1].scatter(prvi_c['median'], prvi_c['std'], color='pink')
ax[2,1].plot(prvi_c['median'], fc_prvi_linreg_predict_y, 'r-')
ax[2,1].text(0.0075,0.00375, f'r-squared = {round(fc_prvi_linreg.rvalue, 2)}')
ax[2,1].set_xlabel('median', fontsize=15)
ax[2,1].locator_params(axis='x', nbins=10)

ax[0,2].set_title('DPSVI', fontsize=25)
ax[0,2].scatter(dpsvi_f['median'], dpsvi_f['std'], color='dodgerblue')
ax[0,2].plot(dpsvi_f['median'], ff_dpsvi_linreg_predict_y, 'r-')
ax[0,2].text(0.3, 0.05, f'r-squared = {round(ff_dpsvi_linreg.rvalue, 2)}')

ax[1,2].scatter(dpsvi_s['median'], dpsvi_s['std'], color='limegreen')
ax[1,2].plot(dpsvi_s['median'], fs_dpsvi_linreg_predict_y, 'r-')
ax[1,2].text(0.2, 0.05, f'r-squared = {round(fs_dpsvi_linreg.rvalue, 2)}')

ax[2,2].scatter(dpsvi_c['median'], dpsvi_c['std'], color='pink')
ax[2,2].plot(dpsvi_c['median'], fc_dpsvi_linreg_predict_y, 'r-')
ax[2,2].text(0.15, 0.02, f'r-squared = {round(fc_dpsvi_linreg.rvalue, 2)}')
ax[2,2].set_xlabel('median', fontsize=15)
ax[2,2].locator_params(axis='x', nbins=10)

ax[0,3].set_title('DPSVIm', fontsize=25)
ax[0,3].scatter(dpsvim_f['median'], dpsvim_f['std'], color='dodgerblue')
ax[0,3].plot(dpsvim_f['median'], ff_dpsvim_linreg_predict_y, 'r-')
ax[0,3].text(0.022, 0.014, f'r-squared = {round(ff_dpsvim_linreg.rvalue, 2)}')

ax[1,3].scatter(dpsvim_s['median'], dpsvim_s['std'], color='limegreen')
ax[1,3].plot(dpsvim_s['median'], fs_dpsvim_linreg_predict_y, 'r-')
ax[1,3].text(0.017, 0.006, f'r-squared = {round(fs_dpsvim_linreg.rvalue, 2)}')#

ax[2,3].scatter(dpsvim_c['median'], dpsvim_c['std'], color='pink')
ax[2,3].plot(dpsvim_c['median'], fc_dpsvim_linreg_predict_y, 'r-')
ax[2,3].text(0.0125, 0.005, f'r-squared = {round(fc_dpsvim_linreg.rvalue, 2)}')
ax[2,3].set_xlabel('median', fontsize=15)
ax[2,3].locator_params(axis='x', nbins=10)

ax[0,4].set_title('RVI', fontsize=25)
ax[0,4].scatter(rvi_f['median'], rvi_f['std'], color='dodgerblue')
ax[0,4].plot(rvi_f['median'], ff_rvi_linreg_predict_y, 'r-')
ax[0,4].text(0.84, 0.24, f'r-squared = {round(ff_rvi_linreg.rvalue, 2)}')

ax[1,4].scatter(rvi_s['median'], rvi_s['std'], color='limegreen')
ax[1,4].plot(rvi_s['median'], fs_rvi_linreg_predict_y, 'r-')
ax[1,4].text(0.85, 0.24, f'r-squared = {round(fs_rvi_linreg.rvalue, 2)}')

ax[2,4].scatter(rvi_c['median'], rvi_c['std'], color='pink')
ax[2,4].plot(rvi_c['median'], fc_rvi_linreg_predict_y, 'r-')
ax[2,4].text(0.95, 0.24, f'r-squared = {round(fc_rvi_linreg.rvalue, 2)}')
ax[2,4].set_xlabel('median', fontsize=15)
ax[2,4].locator_params(axis='x', nbins=10)

# %%
fig, ax = plt.subplots(figsize=(20, 12))

ax.plot(dpsvim_f.index, dpsvim_f['median'], 'r', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax.plot(dpsvim_s.index, dpsvim_s['median'], 'g', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax.plot(dpsvim_c.index, dpsvim_c['median'], 'b', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
