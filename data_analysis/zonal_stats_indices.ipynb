# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dprvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDpRVI_reindex.csv')
dprvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaDpRVI_reindex.csv')
dprvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreDpRVI_reindex.csv')

prvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalPRVI_reindex.csv')
prvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaPRVI_reindex.csv')
prvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestrePRVI_reindex.csv')

dpsvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDPSVI_reindex.csv')
dpsvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaDPSVI_reindex.csv')
dpsvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreDPSVI_reindex.csv')

dpsvim_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDPSVIm_reindex.csv')
dpsvim_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaDPSVIm_reindex.csv')
dpsvim_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreDPSVIm_reindex.csv')

rvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalRVI_reindex.csv')
rvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaRVI_reindex.csv')
rvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreRVI_reindex.csv')

# %%
fig, ax = plt.subplots(5, 1, figsize=(30, 20))

ax[0].vlines(dprvi_f.index, ymin=dprvi_f['percentile_25'], ymax=dprvi_f['percentile_75'], colors='k')
ax[0].plot(dprvi_f.index, dprvi_f['median'], 'g', marker='o')
ax[0].plot(dprvi_f.index, dprvi_f['percentile_25'], 'ok', marker='_')
ax[0].plot(dprvi_f.index, dprvi_f['percentile_75'], 'ok', marker='_')
ax[0].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[0].set_ylim([0.35, 0.75])
ax[0].set_xlim([-1, 149])
ax[0].set_ylabel('DpRVI', fontsize=12)

ax[1].vlines(prvi_f.index, ymin=prvi_f['percentile_25'], ymax=prvi_f['percentile_75'], colors='k')
ax[1].plot(prvi_f.index, prvi_f['median'], 'b', marker='o')
ax[1].plot(prvi_f.index, prvi_f['percentile_25'], 'ok', marker='_')
ax[1].plot(prvi_f.index, prvi_f['percentile_75'], 'ok', marker='_')
ax[1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[1].set_ylim([0, 0.015])
ax[1].set_xlim([-1, 149])
ax[1].set_ylabel('PRVI', fontsize=12)

ax[2].vlines(dpsvi_f.index, ymin=dpsvi_f['percentile_25'], ymax=dpsvi_f['percentile_75'], colors='k')
ax[2].plot(dpsvi_f.index, dpsvi_f['median'], 'r', marker='o')
ax[2].plot(dpsvi_f.index, dpsvi_f['percentile_25'], 'ok', marker='_')
ax[2].plot(dpsvi_f.index, dpsvi_f['percentile_75'], 'ok', marker='_')
ax[2].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[2].set_ylim([-0.1, 0.6])
ax[2].set_xlim([-1, 149])
ax[2].set_ylabel('DPSVI', fontsize=12)

ax[3].vlines(dpsvim_f.index, ymin=dpsvim_f['percentile_25'], ymax=dpsvim_f['percentile_75'], colors='k')
ax[3].plot(dpsvim_f.index, dpsvim_f['median'], 'y', marker='o')
ax[3].plot(dpsvim_f.index, dpsvim_f['percentile_25'], 'ok', marker='_')
ax[3].plot(dpsvim_f.index, dpsvim_f['percentile_75'], 'ok', marker='_')
ax[3].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[3].set_ylim([0, 0.05])
ax[3].set_xlim([-1, 149])
ax[3].set_ylabel('DPSVIm', fontsize=12)

ax[4].vlines(rvi_f.index, ymin=rvi_f['percentile_25'], ymax=rvi_f['percentile_75'], colors='k')
ax[4].plot(rvi_f.index, rvi_f['median'], 'orange', marker='o')
ax[4].plot(rvi_f.index, rvi_f['percentile_25'], 'ok', marker='_')
ax[4].plot(rvi_f.index, rvi_f['percentile_75'], 'ok', marker='_')
ax[4].tick_params(axis='x', which='both', bottom=True, labelbottom=True)
ax[4].set_ylim([0.5, 1.2])
ax[4].set_xlim([-1, 149])
ax[4].set_ylabel('RVI', fontsize=12)

# plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/test.svg', dpi=None, facecolor='w', edgecolor='w',
        orientation='landscape', format='svg', transparent=False)
# Out:
# <ipython-input-3-0a70280cafdd>:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[0].plot(dprvi_f.index, dprvi_f['percentile_25'], 'ok', marker='_')
# <ipython-input-3-0a70280cafdd>:6: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[0].plot(dprvi_f.index, dprvi_f['percentile_75'], 'ok', marker='_')
# <ipython-input-3-0a70280cafdd>:14: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[1].plot(prvi_f.index, prvi_f['percentile_25'], 'ok', marker='_')
# <ipython-input-3-0a70280cafdd>:15: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[1].plot(prvi_f.index, prvi_f['percentile_75'], 'ok', marker='_')
# <ipython-input-3-0a70280cafdd>:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[2].plot(dpsvi_f.index, dpsvi_f['percentile_25'], 'ok', marker='_')
# <ipython-input-3-0a70280cafdd>:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[2].plot(dpsvi_f.index, dpsvi_f['percentile_75'], 'ok', marker='_')
# <ipython-input-3-0a70280cafdd>:32: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[3].plot(dpsvim_f.index, dpsvim_f['percentile_25'], 'ok', marker='_')
# <ipython-input-3-0a70280cafdd>:33: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[3].plot(dpsvim_f.index, dpsvim_f['percentile_75'], 'ok', marker='_')
# <ipython-input-3-0a70280cafdd>:41: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[4].plot(rvi_f.index, rvi_f['percentile_25'], 'ok', marker='_')
# <ipython-input-3-0a70280cafdd>:42: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[4].plot(rvi_f.index, rvi_f['percentile_75'], 'ok', marker='_')

# %% [markdown]
# ## Savanica

# %%
fig, ax = plt.subplots(5, 1, figsize=(30, 20))

ax[0].vlines(dprvi_s.index, ymin=dprvi_s['percentile_25'], ymax=dprvi_s['percentile_75'], colors='k')
ax[0].plot(dprvi_s.index, dprvi_s['median'], 'g', marker='o')
ax[0].plot(dprvi_s.index, dprvi_s['percentile_25'], 'ok', marker='_')
ax[0].plot(dprvi_s.index, dprvi_s['percentile_75'], 'ok', marker='_')
ax[0].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[0].set_ylim([0.40, 0.80])
ax[0].set_xlim([-1, 149])
ax[0].set_ylabel('DpRVI', fontsize=12)

ax[1].vlines(prvi_s.index, ymin=prvi_s['percentile_25'], ymax=prvi_s['percentile_75'], colors='k')
ax[1].plot(prvi_s.index, prvi_s['median'], 'b', marker='o')
ax[1].plot(prvi_s.index, prvi_s['percentile_25'], 'ok', marker='_')
ax[1].plot(prvi_s.index, prvi_s['percentile_75'], 'ok', marker='_')
ax[1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[1].set_ylim([0, 0.016])
ax[1].set_xlim([-1, 149])
ax[1].set_ylabel('PRVI', fontsize=12)

ax[2].vlines(dpsvi_s.index, ymin=dpsvi_s['percentile_25'], ymax=dpsvi_s['percentile_75'], colors='k')
ax[2].plot(dpsvi_s.index, dpsvi_s['median'], 'r', marker='o')
ax[2].plot(dpsvi_s.index, dpsvi_s['percentile_25'], 'ok', marker='_')
ax[2].plot(dpsvi_s.index, dpsvi_s['percentile_75'], 'ok', marker='_')
ax[2].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[2].set_ylim([-0.005, 0.35])
ax[2].set_xlim([-1, 149])
ax[2].set_ylabel('DPSVI', fontsize=12)

ax[3].vlines(dpsvim_s.index, ymin=dpsvim_s['percentile_25'], ymax=dpsvim_s['percentile_75'], colors='k')
ax[3].plot(dpsvim_s.index, dpsvim_s['median'], 'y', marker='o')
ax[3].plot(dpsvim_s.index, dpsvim_s['percentile_25'], 'ok', marker='_')
ax[3].plot(dpsvim_s.index, dpsvim_s['percentile_75'], 'ok', marker='_')
ax[3].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[3].set_ylim([-0.005, 0.030])
ax[3].set_xlim([-1, 149])
ax[3].set_ylabel('DPSVIm', fontsize=12)

ax[4].vlines(rvi_s.index, ymin=rvi_s['percentile_25'], ymax=rvi_s['percentile_75'], colors='k')
ax[4].plot(rvi_s.index, rvi_s['median'], 'orange', marker='o')
ax[4].plot(rvi_s.index, rvi_s['percentile_25'], 'ok', marker='_')
ax[4].plot(rvi_s.index, rvi_s['percentile_75'], 'ok', marker='_')
ax[4].tick_params(axis='x', which='both', bottom=True, labelbottom=True)
ax[4].set_ylim([0.6, 1.4])
ax[4].set_xlim([-1, 149])
ax[4].set_ylabel('RVI', fontsize=12)
# Out:
# <ipython-input-19-a33951180a0c>:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[0].plot(dprvi_s.index, dprvi_s['percentile_25'], 'ok', marker='_')
# <ipython-input-19-a33951180a0c>:6: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[0].plot(dprvi_s.index, dprvi_s['percentile_75'], 'ok', marker='_')
# <ipython-input-19-a33951180a0c>:14: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[1].plot(prvi_s.index, prvi_s['percentile_25'], 'ok', marker='_')
# <ipython-input-19-a33951180a0c>:15: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[1].plot(prvi_s.index, prvi_s['percentile_75'], 'ok', marker='_')
# <ipython-input-19-a33951180a0c>:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[2].plot(dpsvi_s.index, dpsvi_s['percentile_25'], 'ok', marker='_')
# <ipython-input-19-a33951180a0c>:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[2].plot(dpsvi_s.index, dpsvi_s['percentile_75'], 'ok', marker='_')
# <ipython-input-19-a33951180a0c>:32: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[3].plot(dpsvim_s.index, dpsvim_s['percentile_25'], 'ok', marker='_')
# <ipython-input-19-a33951180a0c>:33: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[3].plot(dpsvim_s.index, dpsvim_s['percentile_75'], 'ok', marker='_')
# <ipython-input-19-a33951180a0c>:41: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[4].plot(rvi_s.index, rvi_s['percentile_25'], 'ok', marker='_')
# <ipython-input-19-a33951180a0c>:42: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[4].plot(rvi_s.index, rvi_s['percentile_75'], 'ok', marker='_')
# Text(0, 0.5, 'RVI')

# %% [markdown]
# ##  Campestre

# %%
fig, ax = plt.subplots(5, 1, figsize=(30, 20))

ax[0].vlines(dprvi_c.index, ymin=dprvi_c['percentile_25'], ymax=dprvi_c['percentile_75'], colors='k')
ax[0].plot(dprvi_c.index, dprvi_c['median'], 'g', marker='o')
ax[0].plot(dprvi_c.index, dprvi_c['percentile_25'], 'ok', marker='_')
ax[0].plot(dprvi_c.index, dprvi_c['percentile_75'], 'ok', marker='_')
ax[0].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
#ax[0].set_ylim([0.40, 0.80])
ax[0].set_xlim([-1, 149])
ax[0].set_ylabel('DpRVI', fontsize=12)

ax[1].vlines(prvi_c.index, ymin=prvi_c['percentile_25'], ymax=prvi_c['percentile_75'], colors='k')
ax[1].plot(prvi_c.index, prvi_c['median'], 'b', marker='o')
ax[1].plot(prvi_c.index, prvi_c['percentile_25'], 'ok', marker='_')
ax[1].plot(prvi_c.index, prvi_c['percentile_75'], 'ok', marker='_')
ax[1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
#ax[1].set_ylim([0, 0.016])
ax[1].set_xlim([-1, 149])
ax[1].set_ylabel('PRVI', fontsize=12)

ax[2].vlines(dpsvi_c.index, ymin=dpsvi_c['percentile_25'], ymax=dpsvi_c['percentile_75'], colors='k')
ax[2].plot(dpsvi_c.index, dpsvi_c['median'], 'r', marker='o')
ax[2].plot(dpsvi_c.index, dpsvi_c['percentile_25'], 'ok', marker='_')
ax[2].plot(dpsvi_c.index, dpsvi_c['percentile_75'], 'ok', marker='_')
ax[2].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
#ax[2].set_ylim([-0.005, 0.35])
ax[2].set_xlim([-1, 149])
ax[2].set_ylabel('DPSVI', fontsize=12)

ax[3].vlines(dpsvim_c.index, ymin=dpsvim_c['percentile_25'], ymax=dpsvim_c['percentile_75'], colors='k')
ax[3].plot(dpsvim_c.index, dpsvim_c['median'], 'y', marker='o')
ax[3].plot(dpsvim_c.index, dpsvim_c['percentile_25'], 'ok', marker='_')
ax[3].plot(dpsvim_c.index, dpsvim_c['percentile_75'], 'ok', marker='_')
ax[3].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
#ax[3].set_ylim([-0.005, 0.030])
ax[3].set_xlim([-1, 149])
ax[3].set_ylabel('DPSVIm', fontsize=12)

ax[4].vlines(rvi_c.index, ymin=rvi_c['percentile_25'], ymax=rvi_c['percentile_75'], colors='k')
ax[4].plot(rvi_c.index, rvi_c['median'], 'orange', marker='o')
ax[4].plot(rvi_c.index, rvi_c['percentile_25'], 'ok', marker='_')
ax[4].plot(rvi_c.index, rvi_c['percentile_75'], 'ok', marker='_')
ax[4].tick_params(axis='x', which='both', bottom=True, labelbottom=True)
#ax[4].set_ylim([0.6, 1.4])
ax[4].set_xlim([-1, 149])
ax[4].set_ylabel('RVI', fontsize=12)
# Out:
# <ipython-input-20-aa40f4bb6c9b>:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[0].plot(dprvi_c.index, dprvi_c['percentile_25'], 'ok', marker='_')
# <ipython-input-20-aa40f4bb6c9b>:6: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[0].plot(dprvi_c.index, dprvi_c['percentile_75'], 'ok', marker='_')
# <ipython-input-20-aa40f4bb6c9b>:14: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[1].plot(prvi_c.index, prvi_c['percentile_25'], 'ok', marker='_')
# <ipython-input-20-aa40f4bb6c9b>:15: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[1].plot(prvi_c.index, prvi_c['percentile_75'], 'ok', marker='_')
# <ipython-input-20-aa40f4bb6c9b>:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[2].plot(dpsvi_c.index, dpsvi_c['percentile_25'], 'ok', marker='_')
# <ipython-input-20-aa40f4bb6c9b>:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[2].plot(dpsvi_c.index, dpsvi_c['percentile_75'], 'ok', marker='_')
# <ipython-input-20-aa40f4bb6c9b>:32: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[3].plot(dpsvim_c.index, dpsvim_c['percentile_25'], 'ok', marker='_')
# <ipython-input-20-aa40f4bb6c9b>:33: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[3].plot(dpsvim_c.index, dpsvim_c['percentile_75'], 'ok', marker='_')
# <ipython-input-20-aa40f4bb6c9b>:41: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[4].plot(rvi_c.index, rvi_c['percentile_25'], 'ok', marker='_')
# <ipython-input-20-aa40f4bb6c9b>:42: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[4].plot(rvi_c.index, rvi_c['percentile_75'], 'ok', marker='_')
# Text(0, 0.5, 'RVI')
