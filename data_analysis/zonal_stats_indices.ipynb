# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dprvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDpRVI_reindex.csv')
dprvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaDpRVI_reindex.csv')
dprvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreDpRVI_reindex.csv')

prvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalPRVI_reindex.csv')
prvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaPRVI_reindex.csv')
prvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestrePRVI_reindex.csv')

dpsvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDPSVI_reindex.csv')
dpsvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaDPSVI_reindex.csv')
dpsvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreDPSVI_reindex.csv')

dpsvim_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDPSVIm_reindex.csv')
dpsvim_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaDPSVIm_reindex.csv')
dpsvim_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreDPSVIm_reindex.csv')

rvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalRVI_reindex.csv')
rvi_s = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/savanicaRVI_reindex.csv')
rvi_c = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/campestreRVI_reindex.csv')

# %%
rvi_f['data'] = pd.to_datetime(rvi_f['date'], format='%Y/%m/%d')

rvi_f['month'] = rvi_f['data'].dt.month

rvi_f.loc[rvi_f['month']==1,'mes'] = 'Jan'
rvi_f.loc[rvi_f['month']==2,'mes'] = 'Feb'
rvi_f.loc[rvi_f['month']==3,'mes'] = 'Mar'
rvi_f.loc[rvi_f['month']==4,'mes'] = 'Apr'
rvi_f.loc[rvi_f['month']==5,'mes'] = 'May'
rvi_f.loc[rvi_f['month']==6,'mes'] = 'Jun'
rvi_f.loc[rvi_f['month']==7,'mes'] = 'Jul'
rvi_f.loc[rvi_f['month']==8,'mes'] = 'Aug'
rvi_f.loc[rvi_f['month']==9,'mes'] = 'Sep'
rvi_f.loc[rvi_f['month']==10,'mes'] = 'Oct'
rvi_f.loc[rvi_f['month']==11,'mes'] = 'Nov'
rvi_f.loc[rvi_f['month']==12,'mes'] = 'Dec'

# %% [markdown]
# ## Florestal

# %%
# Boxplots

red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

pink_patch = dict(facecolor='pink', color='k')
blue_patch = dict(facecolor='lightblue', color='k')
green_patch = dict(facecolor='lightgreen', color='k')
orange_patch = dict(facecolor='orange', color='k')
yellow_patch = dict(facecolor='lightyellow', color='k')

fig, ax = plt.subplots(1, 5, figsize=(18,12))

ax[0].boxplot(dprvi_f['median'], patch_artist=True, flierprops=red_circle, boxprops=blue_patch)
ax[0].set_title('DpRVI', fontsize=15, fontweight='bold')
ax[0].tick_params(axis='y', labelsize=14)
ax[0].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[0].set_ylabel('Index value', fontsize=15)

ax[1].boxplot(prvi_f['median'], patch_artist=True, flierprops=red_circle, boxprops=green_patch)
ax[1].set_title('PRVI', fontsize=15, fontweight='bold')
ax[1].tick_params(axis='y', labelsize=14)
ax[1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[2].boxplot(dpsvi_f['median'], patch_artist=True, flierprops=red_circle, boxprops=pink_patch)
ax[2].set_title('DPSVI', fontsize=15, fontweight='bold')
ax[2].tick_params(axis='y', labelsize=14)
ax[2].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[3].boxplot(dpsvim_f['median'], patch_artist=True, flierprops=red_circle, boxprops=orange_patch)
ax[3].set_title('DPSVIm', fontsize=15, fontweight='bold')
ax[3].tick_params(axis='y', labelsize=14)
ax[3].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[4].boxplot(rvi_f['median'], patch_artist=True, flierprops=red_circle, boxprops=yellow_patch)
ax[4].set_title('RVI', fontsize=15, fontweight='bold')
ax[4].tick_params(axis='y', labelsize=14)
ax[4].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# %%
# Temporal profiles

fig, ax = plt.subplots(5, 2, figsize=(30, 20), gridspec_kw={'width_ratios': [20, 1]})

ax[0,0].vlines(dprvi_f.index, ymin=dprvi_f['percentile_25'], ymax=dprvi_f['percentile_75'], colors='k')
ax[0,0].plot(dprvi_f.index, dprvi_f['median'], 'b', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[0,0].plot(dprvi_f.index, dprvi_f['percentile_25'], 'ok', marker='_')
ax[0,0].plot(dprvi_f.index, dprvi_f['percentile_75'], 'ok', marker='_')
ax[0,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0,0].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[0,0].set_ylim([0.35, 0.75])
ax[0,0].set_xlim([-1, 149])
ax[0,0].set_ylabel('DpRVI', fontsize=30)
ax[0,0].locator_params(axis='x', nbins=60)
ax[0,0].locator_params(axis='y', nbins=8)

ax[0,1].boxplot(dprvi_f['median'], patch_artist=True, flierprops=red_circle, boxprops=blue_patch)
ax[0,1].tick_params(axis='y', labelsize=14)
ax[0,1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[1,0].vlines(prvi_f.index, ymin=prvi_f['percentile_25'], ymax=prvi_f['percentile_75'], colors='k')
ax[1,0].plot(prvi_f.index, prvi_f['median'], 'g', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[1,0].plot(prvi_f.index, prvi_f['percentile_25'], 'ok', marker='_')
ax[1,0].plot(prvi_f.index, prvi_f['percentile_75'], 'ok', marker='_')
ax[1,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1,0].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[1,0].set_ylim([0, 0.015])
ax[1,0].set_xlim([-1, 149])
ax[1,0].set_ylabel('PRVI', fontsize=30)
ax[1,0].locator_params(axis='x', nbins=60)
ax[1,0].locator_params(axis='y', nbins=8)

ax[1,1].boxplot(prvi_f['median'], patch_artist=True, flierprops=red_circle, boxprops=green_patch)
ax[1,1].tick_params(axis='y', labelsize=14)
ax[1,1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[2,0].vlines(dpsvi_f.index, ymin=dpsvi_f['percentile_25'], ymax=dpsvi_f['percentile_75'], colors='k')
ax[2,0].plot(dpsvi_f.index, dpsvi_f['median'], 'r', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[2,0].plot(dpsvi_f.index, dpsvi_f['percentile_25'], 'ok', marker='_')
ax[2,0].plot(dpsvi_f.index, dpsvi_f['percentile_75'], 'ok', marker='_')
ax[2,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2,0].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[2,0].set_ylim([-0.1, 0.6])
ax[2,0].set_xlim([-1, 149])
ax[2,0].set_ylabel('DPSVI', fontsize=30)
ax[2,0].locator_params(axis='x', nbins=60)
ax[2,0].locator_params(axis='y', nbins=8)

ax[2,1].boxplot(dpsvi_f['median'], patch_artist=True, flierprops=red_circle, boxprops=pink_patch)
ax[2,1].tick_params(axis='y', labelsize=14)
ax[2,1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[3,0].vlines(dpsvim_f.index, ymin=dpsvim_f['percentile_25'], ymax=dpsvim_f['percentile_75'], colors='k')
ax[3,0].plot(dpsvim_f.index, dpsvim_f['median'], 'orange', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[3,0].plot(dpsvim_f.index, dpsvim_f['percentile_25'], 'ok', marker='_')
ax[3,0].plot(dpsvim_f.index, dpsvim_f['percentile_75'], 'ok', marker='_')
ax[3,0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[3,0].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[3,0].set_ylim([0, 0.05])
ax[3,0].set_xlim([-1, 149])
ax[3,0].set_ylabel('DPSVIm', fontsize=30)
ax[3,0].locator_params(axis='x', nbins=60)
ax[3,0].locator_params(axis='y', nbins=6)

ax[3,1].boxplot(dpsvim_f['median'], patch_artist=True, flierprops=red_circle, boxprops=orange_patch)
ax[3,1].tick_params(axis='y', labelsize=14)
ax[3,1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[4,0].vlines(rvi_f.index, ymin=rvi_f['percentile_25'], ymax=rvi_f['percentile_75'], colors='k')
ax[4,0].plot(rvi_f.index, rvi_f['median'], 'yellow', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[4,0].plot(rvi_f.index, rvi_f['percentile_25'], 'ok', marker='_')
ax[4,0].plot(rvi_f.index, rvi_f['percentile_75'], 'ok', marker='_')
ax[4,0].tick_params(axis='x', which='both', bottom=True, labelbottom=True, length=8, width=2)
ax[4,0].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[4,0].set_ylim([0.5, 1.2])
ax[4,0].set_xlim([-1, 149])
ax[4,0].set_ylabel('RVI', fontsize=30)
ax[4,0].locator_params(axis='y', nbins=8)

ax[4,1].boxplot(rvi_f['median'], patch_artist=True, flierprops=red_circle, boxprops=yellow_patch)
ax[4,1].tick_params(axis='y', labelsize=14)
ax[4,1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# plt.xticks(ticks=rvi_f.index, labels=rvi_f['mes'], rotation=45, fontsize=20)

# ax[4,0].locator_params(axis='x', nbins=60)

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/ff_time_series.svg', dpi=None, facecolor='w', edgecolor='w',
        orientation='landscape', format='svg', transparent=False)
# Out:
# <ipython-input-69-e8c159d7a74d>:7: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[0,0].plot(dprvi_f.index, dprvi_f['percentile_25'], 'ok', marker='_')
# <ipython-input-69-e8c159d7a74d>:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[0,0].plot(dprvi_f.index, dprvi_f['percentile_75'], 'ok', marker='_')
# <ipython-input-69-e8c159d7a74d>:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ok" (-> marker='o'). The keyword argument will take precedence.
#   ax[1,0].plot(prvi_f.index, prvi_f['percentile_25'], 'ok', marker='_')
# ...

# %% [markdown]
# ## Savanica

# %%
# Boxplots

red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

pink_patch = dict(facecolor='pink', color='k')
blue_patch = dict(facecolor='lightblue', color='k')
green_patch = dict(facecolor='lightgreen', color='k')
orange_patch = dict(facecolor='orange', color='k')
yellow_patch = dict(facecolor='lightyellow', color='k')

fig, ax = plt.subplots(1, 5, figsize=(18,12))

ax[0].boxplot(dprvi_s['median'], patch_artist=True, flierprops=red_circle, boxprops=blue_patch)
ax[0].set_title('DpRVI', fontsize=15, fontweight='bold')
ax[0].tick_params(axis='y', labelsize=14)
ax[0].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[0].set_ylabel('Index value', fontsize=15)

ax[1].boxplot(prvi_s['median'], patch_artist=True, flierprops=red_circle, boxprops=green_patch)
ax[1].set_title('PRVI', fontsize=15, fontweight='bold')
ax[1].tick_params(axis='y', labelsize=14)
ax[1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[2].boxplot(dpsvi_s['median'], patch_artist=True, flierprops=red_circle, boxprops=pink_patch)
ax[2].set_title('DPSVI', fontsize=15, fontweight='bold')
ax[2].tick_params(axis='y', labelsize=14)
ax[2].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[3].boxplot(dpsvim_s['median'], patch_artist=True, flierprops=red_circle, boxprops=orange_patch)
ax[3].set_title('DPSVIm', fontsize=15, fontweight='bold')
ax[3].tick_params(axis='y', labelsize=14)
ax[3].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[4].boxplot(rvi_s['median'], patch_artist=True, flierprops=red_circle, boxprops=yellow_patch)
ax[4].set_title('RVI', fontsize=15, fontweight='bold')
ax[4].tick_params(axis='y', labelsize=14)
ax[4].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# %%
# Temporal profiles

fig, ax = plt.subplots(5, 1, figsize=(30, 20))

ax[0].vlines(dprvi_s.index, ymin=dprvi_s['percentile_25'], ymax=dprvi_s['percentile_75'], colors='k')
ax[0].plot(dprvi_s.index, dprvi_s['median'], 'b', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[0].plot(dprvi_s.index, dprvi_s['percentile_25'], 'ok', marker='_')
ax[0].plot(dprvi_s.index, dprvi_s['percentile_75'], 'ok', marker='_')
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[0].set_ylim([0.40, 0.80])
ax[0].set_xlim([-1, 149])
ax[0].set_ylabel('DpRVI', fontsize=30)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=8)

ax[1].vlines(prvi_s.index, ymin=prvi_s['percentile_25'], ymax=prvi_s['percentile_75'], colors='k')
ax[1].plot(prvi_s.index, prvi_s['median'], 'g', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[1].plot(prvi_s.index, prvi_s['percentile_25'], 'ok', marker='_')
ax[1].plot(prvi_s.index, prvi_s['percentile_75'], 'ok', marker='_')
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[1].set_ylim([0, 0.016])
ax[1].set_xlim([-1, 149])
ax[1].set_ylabel('PRVI', fontsize=30)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=8)

ax[2].vlines(dpsvi_s.index, ymin=dpsvi_s['percentile_25'], ymax=dpsvi_s['percentile_75'], colors='k')
ax[2].plot(dpsvi_s.index, dpsvi_s['median'], 'r', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[2].plot(dpsvi_s.index, dpsvi_s['percentile_25'], 'ok', marker='_')
ax[2].plot(dpsvi_s.index, dpsvi_s['percentile_75'], 'ok', marker='_')
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[2].set_ylim([-0.005, 0.35])
ax[2].set_xlim([-1, 149])
ax[2].set_ylabel('DPSVI', fontsize=30)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=8)

ax[3].vlines(dpsvim_s.index, ymin=dpsvim_s['percentile_25'], ymax=dpsvim_s['percentile_75'], colors='k')
ax[3].plot(dpsvim_s.index, dpsvim_s['median'], 'orange', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[3].plot(dpsvim_s.index, dpsvim_s['percentile_25'], 'ok', marker='_')
ax[3].plot(dpsvim_s.index, dpsvim_s['percentile_75'], 'ok', marker='_')
ax[3].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[3].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[3].set_ylim([-0.005, 0.030])
ax[3].set_xlim([-1, 149])
ax[3].set_ylabel('DPSVIm', fontsize=30)
ax[3].locator_params(axis='x', nbins=60)
ax[3].locator_params(axis='y', nbins=8)

ax[4].vlines(rvi_s.index, ymin=rvi_s['percentile_25'], ymax=rvi_s['percentile_75'], colors='k')
ax[4].plot(rvi_s.index, rvi_s['median'], 'yellow', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[4].plot(rvi_s.index, rvi_s['percentile_25'], 'ok', marker='_')
ax[4].plot(rvi_s.index, rvi_s['percentile_75'], 'ok', marker='_')
ax[4].tick_params(axis='x', which='both', bottom=True, labelbottom=True, length=8, width=2)
ax[4].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[4].set_ylim([0.6, 1.4])
ax[4].set_xlim([-1, 149])
ax[4].set_ylabel('RVI', fontsize=30)
ax[4].locator_params(axis='x', nbins=60)
ax[4].locator_params(axis='y', nbins=8)

plt.xticks(ticks=rvi_f.index, labels=rvi_f['mes'], rotation=45, fontsize=20)

ax[4].locator_params(axis='x', nbins=60)

# plt.savefig('C:/Users/jales/Desktop/fs_time_series.svg', dpi=None, facecolor='w', edgecolor='w',
#         orientation='landscape', format='svg', transparent=False)

# %% [markdown]
# ##  Campestre

# %%
# Boxplots

red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

pink_patch = dict(facecolor='pink', color='k')
blue_patch = dict(facecolor='lightblue', color='k')
green_patch = dict(facecolor='lightgreen', color='k')
orange_patch = dict(facecolor='orange', color='k')
yellow_patch = dict(facecolor='lightyellow', color='k')

fig, ax = plt.subplots(1, 5, figsize=(18,12))

ax[0].boxplot(dprvi_c['median'], patch_artist=True, flierprops=red_circle, boxprops=blue_patch)
ax[0].set_title('DpRVI', fontsize=15, fontweight='bold')
ax[0].tick_params(axis='y', labelsize=14)
ax[0].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax[0].set_ylabel('Index value', fontsize=15)

ax[1].boxplot(prvi_c['median'], patch_artist=True, flierprops=red_circle, boxprops=green_patch)
ax[1].set_title('PRVI', fontsize=15, fontweight='bold')
ax[1].tick_params(axis='y', labelsize=14)
ax[1].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[2].boxplot(dpsvi_c['median'], patch_artist=True, flierprops=red_circle, boxprops=pink_patch)
ax[2].set_title('DPSVI', fontsize=15, fontweight='bold')
ax[2].tick_params(axis='y', labelsize=14)
ax[2].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[3].boxplot(dpsvim_c['median'], patch_artist=True, flierprops=red_circle, boxprops=orange_patch)
ax[3].set_title('DPSVIm', fontsize=15, fontweight='bold')
ax[3].tick_params(axis='y', labelsize=14)
ax[3].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

ax[4].boxplot(rvi_c['median'], patch_artist=True, flierprops=red_circle, boxprops=yellow_patch)
ax[4].set_title('RVI', fontsize=15, fontweight='bold')
ax[4].tick_params(axis='y', labelsize=14)
ax[4].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# %%
# Temporal profiles

fig, ax = plt.subplots(5, 1, figsize=(30, 20))

ax[0].vlines(dprvi_c.index, ymin=dprvi_c['percentile_25'], ymax=dprvi_c['percentile_75'], colors='k')
ax[0].plot(dprvi_c.index, dprvi_c['median'], 'b', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[0].plot(dprvi_c.index, dprvi_c['percentile_25'], 'ok', marker='_')
ax[0].plot(dprvi_c.index, dprvi_c['percentile_75'], 'ok', marker='_')
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[0].set_ylim([0.40, 0.75])
ax[0].set_xlim([-1, 149])
ax[0].set_ylabel('DpRVI', fontsize=30)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=8)

ax[1].vlines(prvi_c.index, ymin=prvi_c['percentile_25'], ymax=prvi_c['percentile_75'], colors='k')
ax[1].plot(prvi_c.index, prvi_c['median'], 'g', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[1].plot(prvi_c.index, prvi_c['percentile_25'], 'ok', marker='_')
ax[1].plot(prvi_c.index, prvi_c['percentile_75'], 'ok', marker='_')
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[1].set_ylim([0, 0.016])
ax[1].set_xlim([-1, 149])
ax[1].set_ylabel('PRVI', fontsize=30)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=8)

ax[2].vlines(dpsvi_c.index, ymin=dpsvi_c['percentile_25'], ymax=dpsvi_c['percentile_75'], colors='k')
ax[2].plot(dpsvi_c.index, dpsvi_c['median'], 'r', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[2].plot(dpsvi_c.index, dpsvi_c['percentile_25'], 'ok', marker='_')
ax[2].plot(dpsvi_c.index, dpsvi_c['percentile_75'], 'ok', marker='_')
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[2].set_ylim([-0.1, 0.5])
ax[2].set_xlim([-1, 149])
ax[2].set_ylabel('DPSVI', fontsize=30)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=8)

ax[3].vlines(dpsvim_c.index, ymin=dpsvim_c['percentile_25'], ymax=dpsvim_c['percentile_75'], colors='k')
ax[3].plot(dpsvim_c.index, dpsvim_c['median'], 'orange', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[3].plot(dpsvim_c.index, dpsvim_c['percentile_25'], 'ok', marker='_')
ax[3].plot(dpsvim_c.index, dpsvim_c['percentile_75'], 'ok', marker='_')
ax[3].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[3].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[3].set_ylim([-0.005, 0.035])
ax[3].set_xlim([-1, 149])
ax[3].set_ylabel('DPSVIm', fontsize=30)
ax[3].locator_params(axis='x', nbins=60)
ax[3].locator_params(axis='y', nbins=8)

ax[4].vlines(rvi_c.index, ymin=rvi_c['percentile_25'], ymax=rvi_c['percentile_75'], colors='k')
ax[4].plot(rvi_c.index, rvi_c['median'], 'yellow', marker='o', markersize=10, markeredgewidth=0.5, markeredgecolor='k')
ax[4].plot(rvi_c.index, rvi_c['percentile_25'], 'ok', marker='_')
ax[4].plot(rvi_c.index, rvi_c['percentile_75'], 'ok', marker='_')
ax[4].tick_params(axis='x', which='both', bottom=True, labelbottom=True, length=8, width=2)
ax[4].tick_params(axis='y', length=5, width=1.5, labelsize=20)
ax[4].set_ylim([0.6, 1.3])
ax[4].set_xlim([-1, 149])
ax[4].set_ylabel('RVI', fontsize=30)
ax[4].locator_params(axis='x', nbins=60)
ax[4].locator_params(axis='y', nbins=8)

plt.xticks(ticks=rvi_f.index, labels=rvi_f['mes'], rotation=45, fontsize=20)

ax[4].locator_params(axis='x', nbins=60)

# plt.savefig('C:/Users/jales/Desktop/fc_time_series_ok.svg', dpi=None, facecolor='w', edgecolor='w',
#         orientation='landscape', format='svg', transparent=False)
