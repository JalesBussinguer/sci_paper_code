# %%
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import os

from rasterstats import zonal_stats

# %%
form_florestal = gpd.read_file('D:/thesis_data/ROI/classes/form_florestal_10m_32723.GEOJSON')

# %%
indices = os.listdir('D:/thesis_data/VEG_INDICES/2021')

# %%
df_stats = pd.DataFrame()

for index, image in enumerate(indices):

    if image.endswith('.tif'):

        date = indices[index].split('.')[0]

        florestal = zonal_stats(form_florestal, 'D:/thesis_data/VEG_INDICES/2021/' + str(image), band=1, nodata=np.nan, stats=['median', 'mean', 'std'])

        stats = pd.DataFrame(florestal)
        stats['date'] = date
        df_stats = pd.concat([stats, df_stats], ignore_index=True)

        print(f'data of {date} collected!')
# Out:
# data of 20210103 collected!
# data of 20210115 collected!
# data of 20210127 collected!
# data of 20210208 collected!
# data of 20210220 collected!
# data of 20210304 collected!
# data of 20210316 collected!
# data of 20210328 collected!
# data of 20210409 collected!
# data of 20210421 collected!
# data of 20210503 collected!
# data of 20210515 collected!
# data of 20210527 collected!
# data of 20210608 collected!
# data of 20210620 collected!
# data of 20210702 collected!
# data of 20210714 collected!
# data of 20210726 collected!
# data of 20210807 collected!
# data of 20210819 collected!
# data of 20210831 collected!
# data of 20210912 collected!
# data of 20210924 collected!
# data of 20211006 collected!
# data of 20211018 collected!
# data of 20211030 collected!
# data of 20211111 collected!
# data of 20211123 collected!
# data of 20211205 collected!
# data of 20211229 collected!

# %%
df_stats.head(30)
# Out:
#         mean       std    median      date
# 0   0.540866  0.134692  0.537038  20211229
# 1   0.536249  0.135689  0.531162  20211205
# 2   0.544760  0.135834  0.540431  20211123
# 3   0.447150  0.442694  0.537983  20211111
# 4   0.534099  0.134317  0.529146  20211030
# 5   0.553763  0.136800  0.550149  20211018
# 6   0.541176  0.135871  0.536462  20211006
# 7   0.551039  0.136642  0.547005  20210924
# 8   0.551941  0.136092  0.547769  20210912
# 9   0.561872  0.136333  0.557869  20210831
# 10  0.536546  0.135434  0.531940  20210819
# 11  0.522108  0.134783  0.516508  20210807
# 12  0.518102  0.134501  0.512023  20210726
# 13  0.318611  0.598430  0.488731  20210714
# 14  0.518902  0.134787  0.513140  20210702
# 15  0.521050  0.134515  0.515097  20210620
# 16  0.514050  0.134784  0.508022  20210608
# 17  0.522306  0.134622  0.516323  20210527
# 18  0.518052  0.134140  0.512079  20210515
# 19  0.413199  0.450262  0.500085  20210503
# 20  0.531141  0.135697  0.525784  20210421
# 21  0.539139  0.134591  0.534380  20210409
# 22  0.519783  0.134814  0.514090  20210328
# 23  0.536933  0.135568  0.532471  20210316
# 24  0.527180  0.135084  0.521900  20210304
# 25  0.548503  0.136036  0.544654  20210220
# 26  0.553845  0.135904  0.549916  20210208
# 27  0.549094  0.135248  0.545201  20210127
# 28  0.545484  0.135420  0.541665  20210115
# 29  0.547765  0.135346  0.543676  20210103

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(df_stats.date, df_stats['median'], 'g', marker='o', label='Mediana - VH')

plt.xticks(rotation=45)

#plt.ylim(-18.0, -12.0)
plt.legend()
ax.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')
