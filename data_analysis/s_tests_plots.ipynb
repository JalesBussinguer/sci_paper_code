# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dprvi_f = pd.read_csv('D:/thesis_data/VEG_INDICES/stats/florestalDpRVI_reindex.csv')

ff_rates = pd.read_csv('D:/thesis_data/VEG_INDICES/rates/FF_rates.csv')
fs_rates = pd.read_csv('D:/thesis_data/VEG_INDICES/rates/FS_rates.csv')
fc_rates = pd.read_csv('D:/thesis_data/VEG_INDICES/rates/FC_rates.csv')

ff_fs_rates = pd.read_csv('D:/thesis_data/VEG_INDICES/rates/FF_FS_rates.csv')
ff_fc_rates = pd.read_csv('D:/thesis_data/VEG_INDICES/rates/FF_FC_rates.csv')
fs_fc_rates = pd.read_csv('D:/thesis_data/VEG_INDICES/rates/FS_FC_rates.csv')

# %%
def month_season_detector(df):

    df['data'] = pd.to_datetime(df['date'], format='%Y/%m/%d')

    df['month'] = df['data'].dt.month

    df.loc[df['month']==1,'mes'] = 'Jan'
    df.loc[df['month']==2,'mes'] = 'Feb'
    df.loc[df['month']==3,'mes'] = 'Mar'
    df.loc[df['month']==4,'mes'] = 'Apr'
    df.loc[df['month']==5,'mes'] = 'May'
    df.loc[df['month']==6,'mes'] = 'Jun'
    df.loc[df['month']==7,'mes'] = 'Jul'
    df.loc[df['month']==8,'mes'] = 'Aug'
    df.loc[df['month']==9,'mes'] = 'Sep'
    df.loc[df['month']==10,'mes'] = 'Oct'
    df.loc[df['month']==11,'mes'] = 'Nov'
    df.loc[df['month']==12,'mes'] = 'Dec'

    df.loc[df['month']==1,'season'] = 'wet'
    df.loc[df['month']==2,'season'] = 'wet'
    df.loc[df['month']==3,'season'] = 'wet'
    df.loc[df['month']==4,'season'] = 'wet'
    df.loc[df['month']==5,'season'] = 'dry'
    df.loc[df['month']==6,'season'] = 'dry'
    df.loc[df['month']==7,'season'] = 'dry'
    df.loc[df['month']==8,'season'] = 'dry'
    df.loc[df['month']==9,'season'] = 'dry'
    df.loc[df['month']==10,'season'] = 'wet'
    df.loc[df['month']==11,'season'] = 'wet'
    df.loc[df['month']==12,'season'] = 'wet'

# %%
dprvi_f['data'] = pd.to_datetime(dprvi_f['date'], format='%Y/%m/%d')

dprvi_f['month'] = dprvi_f['data'].dt.month

dprvi_f.loc[dprvi_f['month']==1,'mes'] = 'Jan'
dprvi_f.loc[dprvi_f['month']==2,'mes'] = 'Feb'
dprvi_f.loc[dprvi_f['month']==3,'mes'] = 'Mar'
dprvi_f.loc[dprvi_f['month']==4,'mes'] = 'Apr'
dprvi_f.loc[dprvi_f['month']==5,'mes'] = 'May'
dprvi_f.loc[dprvi_f['month']==6,'mes'] = 'Jun'
dprvi_f.loc[dprvi_f['month']==7,'mes'] = 'Jul'
dprvi_f.loc[dprvi_f['month']==8,'mes'] = 'Aug'
dprvi_f.loc[dprvi_f['month']==9,'mes'] = 'Sep'
dprvi_f.loc[dprvi_f['month']==10,'mes'] = 'Oct'
dprvi_f.loc[dprvi_f['month']==11,'mes'] = 'Nov'
dprvi_f.loc[dprvi_f['month']==12,'mes'] = 'Dec'

# %%
red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

pink_patch = dict(facecolor='pink', color='k')
blue_patch = dict(facecolor='lightblue', color='k')
green_patch = dict(facecolor='lightgreen', color='k')
orange_patch = dict(facecolor='orange', color='k')
yellow_patch = dict(facecolor='yellow', color='k')

median_patch = dict(color='red')

# %%
index = ff_rates.index
rates_f = ff_rates
rates_s = fs_rates
rates_c = fc_rates

# %%
# Temporal profiles

fig, ax = plt.subplots(5, 1, figsize=(18, 6))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1.5, colors='k', linewidth=2)

ax[0].plot(index, rates_f['dprvi'], 'royalblue', marker='o', linewidth=3)
ax[0].plot(index, rates_s['dprvi'], 'royalblue', marker='o', linewidth=3)
ax[0].plot(index, rates_c['dprvi'], 'royalblue', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=15)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.99, 1.005])
ax[0].set_ylabel('DpRVI', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=4)


ax[1].plot(index, rates['prvi'], 'limegreen', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=15)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.88, 1.02])
ax[1].set_ylabel('PRVI', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=8)


ax[2].plot(index, rates['dpsvi'], 'red', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=15)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.92, 1.02])
ax[2].set_ylabel('DPSVI', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=8)


ax[3].plot(index, rates['dpsvim'], 'orange', marker='o', linewidth=3)
ax[3].set_xticks(ticks=dprvi_f.index)
ax[3].tick_params(axis='y', length=5, width=1.5, labelsize=15)
ax[3].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[3].set_xlim([-1, 149])
ax[3].set_ylim([0.94, 1.01])
ax[3].set_ylabel('DPSVIm', fontsize=15)
ax[3].locator_params(axis='x', nbins=60)
ax[3].locator_params(axis='y', nbins=8)


ax[4].plot(index, rates['rvi'], 'y', marker='o', linewidth=3)
ax[4].set_xticks(ticks=dprvi_f.index)
ax[4].tick_params(axis='y', length=5, width=1.5, labelsize=15)
ax[4].tick_params(axis='x', which='both', bottom=True, labelbottom=True, length=8, width=2)
ax[4].set_xlim([-1, 149])
ax[4].set_ylim([0.96, 1])
ax[4].set_ylabel('RVI', fontsize=15)
ax[4].locator_params(axis='x', nbins=60)
ax[4].locator_params(axis='y', nbins=8)
ax[4].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

# plt.savefig('C:/Users/jales/Desktop/fs_fc_rates.svg', dpi=None, facecolor='w', edgecolor='w',
#     orientation='landscape', format='svg', transparent=False)

# %%
# Temporal profiles

fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1.5, colors='k', linewidth=2)

ax[0].plot(index, rates_f['dprvi'], 'royalblue', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.985, 1.003])
ax[0].set_ylabel('GF', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=4)


ax[1].plot(index, rates_s['dprvi'], 'royalblue', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.985, 1.003])
ax[1].set_ylabel('SL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=6)


ax[2].plot(index, rates_c['dprvi'], 'royalblue', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.985, 1.003])
ax[2].set_ylabel('GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=6)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/dprvi_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)

# %%
# Temporal profiles

fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1, colors='k', linewidth=2)

ax[0].plot(index, rates_f['prvi'], 'limegreen', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.85, 1.00])
ax[0].set_ylabel('GF', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=4)


ax[1].plot(index, rates_s['prvi'], 'limegreen', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.85, 1])
ax[1].set_ylabel('SL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=6)


ax[2].plot(index, rates_c['prvi'], 'limegreen', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.85, 1])
ax[2].set_ylabel('GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=6)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/prvi_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)

# %%
# Temporal profiles

fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1, colors='k', linewidth=2)

ax[0].plot(index, rates_f['dpsvi'], 'crimson', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.85, 1.00])
ax[0].set_ylabel('GF', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=4)


ax[1].plot(index, rates_s['dpsvi'], 'crimson', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.85, 1])
ax[1].set_ylabel('SL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=4)


ax[2].plot(index, rates_c['dpsvi'], 'crimson', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.85, 1])
ax[2].set_ylabel('GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=4)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/dpsvi_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)

# %%
# Temporal profiles

fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1, colors='k', linewidth=2)

ax[0].plot(index, rates_f['dpsvim'], 'orange', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.90, 1.00])
ax[0].set_ylabel('GF', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=3)


ax[1].plot(index, rates_s['dpsvim'], 'orange', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.88, 1])
ax[1].set_ylabel('SL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=4)


ax[2].plot(index, rates_c['dpsvim'], 'orange', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.90, 1])
ax[2].set_ylabel('GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=3)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/dpsvim_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)

# %%
# Temporal profiles

fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1, colors='k', linewidth=2)

ax[0].plot(index, rates_f['rvi'], 'gold', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.94, 1.00])
ax[0].set_ylabel('GF', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=4)


ax[1].plot(index, rates_s['rvi'], 'gold', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.94, 1])
ax[1].set_ylabel('SL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=4)


ax[2].plot(index, rates_c['rvi'], 'gold', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.94, 1])
ax[2].set_ylabel('GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=4)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/rvi_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)

# %% [markdown]
# ## Interclass Rates

# %%
ff_fc_rates
# Out:
#         dprvi      prvi     dpsvi    dpsvim       rvi
# 0    0.997551  0.984082  0.993061  1.000000  0.977551
# 1    0.999184  0.923265  0.964082  0.995510  0.984082
# 2    0.998367  0.964082  0.984490  0.998776  0.982449
# 3    0.999184  0.959184  0.982041  0.999184  0.982857
# 4    0.998776  0.929796  0.941224  0.991837  0.991837
# ..        ...       ...       ...       ...       ...
# 144  0.997143  0.992245  0.996735  1.000000  0.971429
# 145  0.998776  0.936327  0.957551  0.984490  0.990204
# 146  0.998776  0.928980  0.947347  0.994286  0.980816
# 147  0.995510  0.937551  0.978367  0.996735  0.983265
# 148  0.998367  0.973061  0.991429  0.999592  0.976327
#
# [149 rows x 5 columns]

# %%
# Temporal profiles

fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1.5, colors='k', linewidth=2)

ax[0].plot(index, ff_fs_rates['dprvi'], 'royalblue', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.99, 1.003])
ax[0].set_ylabel('GF-SL', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=3)


ax[1].plot(index, ff_fc_rates['dprvi'], 'royalblue', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.99, 1.003])
ax[1].set_ylabel('GF-GL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=3)


ax[2].plot(index, fs_fc_rates['dprvi'], 'royalblue', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.99, 1.003])
ax[2].set_ylabel('SL-GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=3)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/interclass_dprvi_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)

# %%
fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1.5, colors='k', linewidth=2)

ax[0].plot(index, ff_fs_rates['prvi'], 'limegreen', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.85, 1.03])
ax[0].set_ylabel('GF-SL', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=6)


ax[1].plot(index, ff_fc_rates['prvi'], 'limegreen', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.85, 1.03])
ax[1].set_ylabel('GF-GL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=6)


ax[2].plot(index, fs_fc_rates['prvi'], 'limegreen', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.85, 1.03])
ax[2].set_ylabel('SL-GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=6)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/interclass_prvi_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)

# %%
fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1.5, colors='k', linewidth=2)

ax[0].plot(index, ff_fs_rates['dpsvi'], 'crimson', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.90, 1.03])
ax[0].set_ylabel('GF-SL', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=4)


ax[1].plot(index, ff_fc_rates['dpsvi'], 'crimson', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.90, 1.03])
ax[1].set_ylabel('GF-GL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=4)


ax[2].plot(index, fs_fc_rates['dpsvi'], 'crimson', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.90, 1.03])
ax[2].set_ylabel('SL-GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=4)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/interclass_dpsvi_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)

# %%
fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1.5, colors='k', linewidth=2)

ax[0].plot(index, ff_fs_rates['dpsvim'], 'orange', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.90, 1.03])
ax[0].set_ylabel('GF-SL', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=4)


ax[1].plot(index, ff_fc_rates['dpsvim'], 'orange', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.90, 1.03])
ax[1].set_ylabel('GF-GL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=4)


ax[2].plot(index, fs_fc_rates['dpsvim'], 'orange', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.90, 1.03])
ax[2].set_ylabel('SL-GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=4)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/interclass_dpsvim_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)

# %%
fig, ax = plt.subplots(3, 1, figsize=(18, 3))

ax[0].vlines(dprvi_f.index[9], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[21], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[39], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[50], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[67], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[80], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[98], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[111], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[128], ymin=0.5, ymax=1.5, colors='k', linewidth=2)
ax[0].vlines(dprvi_f.index[141], ymin=0.5, ymax=1.5, colors='k', linewidth=2)

ax[0].plot(index, ff_fs_rates['rvi'], 'gold', marker='o', linewidth=3)
ax[0].set_xticks(ticks=dprvi_f.index)
ax[0].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[0].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[0].set_xlim([-1, 149])
ax[0].set_ylim([0.95, 1.01])
ax[0].set_ylabel('GF-SL', fontsize=15)
ax[0].locator_params(axis='x', nbins=60)
ax[0].locator_params(axis='y', nbins=4)


ax[1].plot(index, ff_fc_rates['rvi'], 'gold', marker='o', linewidth=3)
ax[1].set_xticks(ticks=dprvi_f.index)
ax[1].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[1].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=False, length=8, width=2)
ax[1].set_xlim([-1, 149])
ax[1].set_ylim([0.95, 1.01])
ax[1].set_ylabel('GF-GL', fontsize=15)
ax[1].locator_params(axis='x', nbins=60)
ax[1].locator_params(axis='y', nbins=4)


ax[2].plot(index, fs_fc_rates['rvi'], 'gold', marker='o', linewidth=3)
ax[2].set_xticks(ticks=dprvi_f.index)
ax[2].tick_params(axis='y', length=5, width=1.5, labelsize=12)
ax[2].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True, length=8, width=2)
ax[2].set_xlim([-1, 149])
ax[2].set_ylim([0.95, 1.01])
ax[2].set_ylabel('SL-GL', fontsize=15)
ax[2].locator_params(axis='x', nbins=60)
ax[2].locator_params(axis='y', nbins=5)
ax[2].set_xticklabels(labels=dprvi_f['mes'], fontdict={'fontsize': 15, 'rotation': 45, 'horizontalalignment': 'center'})

plt.tight_layout()

plt.savefig('C:/Users/jales/Desktop/interclass_rvi_rates.svg', dpi=None, facecolor='w', edgecolor='w',
    orientation='landscape', format='svg', transparent=False)
